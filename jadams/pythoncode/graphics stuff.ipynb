# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib notebook

# %%
fig1,ax1 = plt.subplots()
ax1.clear()
ax1.errorbar([1,2,3],[2,2,5],[.1,.1,.2])
# Out:
# <img src="data:image/png;base64,...">
# <Container object of 3 artists>

# %%
fig2,ax2 = plt.subplots()
ax2.plot([1,2],[4,3])
# Out:
# <img src="data:image/png;base64,...">

# %%
ax1.errorbar([1,2],[4,3],[.1,.1])
# Out:
# <Container object of 3 artists>
