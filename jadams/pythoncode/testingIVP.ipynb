# %%
import numpy as np  
from scipy.integrate import solve_ivp 
import matplotlib.pyplot as plt

# %%
def exponential_decay(t, y): return -0.5 * y
sol = solve_ivp(exponential_decay, [0, 10], [2, 4, 8])
print(sol.t)
print(sol.y)
# Out:
# [ 0.          0.11487653  1.26364188  3.06061781  4.81611105  6.57445806
#   8.33328988 10.        ]
# [[2.         1.88836035 1.06327177 0.43319312 0.18017253 0.07483045
#   0.03107158 0.01350781]
#  [4.         3.7767207  2.12654355 0.86638624 0.36034507 0.14966091
#   0.06214316 0.02701561]
#  [8.         7.5534414  4.25308709 1.73277247 0.72069014 0.29932181
#   0.12428631 0.05403123]]

# %%
def upward_cannon(t, y): return [y[1], -0.5]
sol = solve_ivp(upward_cannon, [0, 100], [0, 10])
print(sol.t)
# Out:
# [0.00000000e+00 9.99900010e-05 1.09989001e-03 1.10988901e-02
#  1.11088891e-01 1.11098890e+00 1.11099890e+01 1.00000000e+02]

# %%
def hit_ground(t, y): return y[1]
hit_ground.terminal = True
hit_ground.direction = -1
sol = solve_ivp(upward_cannon, [0, 100], [0, 10], events=hit_ground)
print(sol.t_events)
print(sol.t)
# Out:
# [array([20.])]
# [0.00000000e+00 9.99900010e-05 1.09989001e-03 1.10988901e-02
#  1.11088891e-01 1.11098890e+00 1.11099890e+01 2.00000000e+01]

# %%
def rhs(t,Y,params):
# def rhs(t,Y,args=(params,)):
    a,b,c = params
    dY = np.zeros_like(Y)
    k = 1.0
    dY[0] = k - (1 - 5/Y[1])*(3+2/Y[1])
    dY[1] = Y[0]
    dY[2] = 1/Y[1]**2
    return dY

# %%
params = [1,2,3]
Y0 = np.array([0,1,0]) 
sol = solve_ivp(rhs, [0,10], Y0, args=(params,), dense_output=True)
print(sol.t)
print(np.shape(sol.y))
plt.figure()
plt.plot(sol.t,sol.y.T)



# t = np.linspace(0, 10, 1001) 
# Y = sol.sol(t) 

# plt.plot(t, Y[1],'-', label='r(t)') 
# plt.plot(t, Y[2],'-', label='phi(t)')
# plt.legend(loc='best')
# plt.xlabel('T')
# Out:
# [0.00000000e+00 4.75176318e-05 5.22693950e-04 5.27445713e-03
#  5.27920889e-02 1.87748843e-01 3.77652621e-01 6.67002854e-01
#  1.23122248e+00 2.43036206e+00 5.03180747e+00 9.39858447e+00
#  1.00000000e+01]
# (3, 13)
# [<matplotlib.lines.Line2D at 0x14cad8df0>,
#  <matplotlib.lines.Line2D at 0x14cad8e50>,
#  <matplotlib.lines.Line2D at 0x14cad8e80>]
