# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib notebook
data = [\
0.19,                 8.23,  
0.16,                 8.14,  
0.13,                 8.83,   
0.10,                10.19,   
0.07,                12.70,   
0.04,                17.09  ]
data = np.reshape(data,(6,2))
x = 0.2-data[:,0]
y = data[:,1]
ytheory = 8.0 + x**3*2200
plt.plot(x,y,'o',x,ytheory)
plt.grid('on')
plt.xlabel('0.2 - x0')
plt.ylabel('#layers')
plt.legend(['obs', 'ax^3'])
# Out:
# <img src="data:image/png;base64,...">
