# %%
import numpy as np
import matplotlib.pylab as plt

# %%
# %matplotlib notebook

# %%
data = np.loadtxt('GI parameters - Reference limit cycle (lambda values).txt')
sigmaI_corner = data[:,0]
lambda_value = data[:,1]

# %%
plt.figure()
plt.plot(sigmaI_corner,lambda_value,'+-')
plt.xlabel(r'$\sigma_{I,corner}$')
plt.ylabel('lambda')
# Out:
# <img src="data:image/png;base64,..." width="639.6666666666666">
# Text(0, 0.5, 'lambda')
