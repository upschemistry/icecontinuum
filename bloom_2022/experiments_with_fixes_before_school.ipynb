# %%
import numpy as np
from matplotlib import pyplot as plt
from matplotlib import rcParams
import time
from copy import copy

#from sim_handling import Simulation,loadSim #uses ds7
from sim_handling2 import Simulation,loadSim #ds8: faster, more space efficient
from diffusionstuff8 import f0d,f1d,f2d, getsigmastep_2d
from matplotlib.animation import PillowWriter
# Out:
# C:\Users\Max-PC\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\llvmlite\llvmpy\__init__.py:3: UserWarning: The module `llvmlite.llvmpy` is deprecated and will be removed in the future.
#   warnings.warn(
# C:\Users\Max-PC\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\llvmlite\llvmpy\core.py:8: UserWarning: The module `llvmlite.llvmpy.core` is deprecated and will be removed in the future. Equivalent functionality is provided by `llvmlite.ir`.
#   warnings.warn(
# C:\Users\Max-PC\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\llvmlite\llvmpy\passes.py:17: UserWarning: The module `llvmlite.llvmpy.passes` is deprecated and will be removed in the future. If you are using this code, it should be inlined into your own project.
#   warnings.warn(

# %%
# %matplotlib widget

#set figsize to be big (12,12) inches
#rcParams['figure.figsize'] = 10,10

# %% [markdown]
# assymettric 2d growth

# %%
#load a simulation

#load the ablation with initial noise run
#test_2d_asym = loadSim('f2d_simulation_asymmetric250_200_500layers_center_reduction0.1_D_2_RK45_sigmamax_-0.01noisyinit_True.pkl')

#load the growth with initial noise run
#test_2d_asym = loadSim('f2d_simulation_asymmetric250_200_500layers_center_reduction0.1_D_2_RK45_sigmamax_0.2noisyinit_True.pkl')

# %%
#set up and run and plot a new simulation
test_2d_asym = Simulation(f2d, (200,250), method='RK45')

test_2d_asym.discretization_halt = False

#try a noisy simulation
test_2d_asym.noisy_init = False

test_2d_asym.float_params['DoverdeltaX2'] *= 2 
test_2d_asym.layermax = 400
#test_2d_asym.sigmastepmax= -0.01 #ablation
test_2d_asym.sigmastepmax= 0.195 #growth #NOTE changed to test nakaya diagram - lower suipersaturation = simpler, faceted growth instead of dendritic?
test_2d_asym.center_reduction = .05#1
#test_2d_asym.deltaT *= 10 #increase time step to decrease number of steps saved

#_plot = test_2d_asym.plot(tot=True,completion=1)
#anim = test_2d_asym.animate(ice=True,surface=True, ret=True, focus_on_growth=True)

# %%
my_id=['asymmetric'+str(test_2d_asym.shape[0])+'_'+str(test_2d_asym.shape[1]),str(test_2d_asym.layermax)+'layers',
                                'center_reduction'+str(test_2d_asym.center_reduction),  'D_2', test_2d_asym.method, 'sigmamax_'+str(test_2d_asym.sigmastepmax) +'noisyinit_'+str(test_2d_asym.noisy_init)] #'Cy_0_Dy0',
my_filename = ''.join([i+'_' for i in my_id])

# %%
#calcs to graph asymmetric sigmastep2d
xs,ys = test_2d_asym.x, test_2d_asym.y #linspace
sigma = getsigmastep_2d(xs,ys, test_2d_asym.center_reduction, test_2d_asym.sigmastepmax)
ygrid,xgrid = np.meshgrid(ys,xs) #2d mesh for plotting

# %%
#countour plot of sigmastep 2d
print(xs.shape,ys.shape,sigma.shape)
fig,ax = plt.subplots()
CS = ax.contourf(xgrid,ygrid,sigma*100,np.arange(np.min(sigma*100)-0.01,np.max(sigma*100)+0.01,0.01))
#CS = ax.contourf(xgrid,ygrid,xgrid) #graph x
#CS = ax.contourf(xgrid,ygrid,ygrid) #graph y
ax.set_xlabel(r'$x (\mu m)$', fontsize=20)
ax.set_ylabel(r'$y (\mu m)$', fontsize=20)
plt.grid(True)
plt.gca().set_aspect('equal')
fig.colorbar(CS)
plt.title('%supersaturation (getsigmastep_2d)')
print(xgrid.shape,ygrid.shape)
# Out:
# (200,) (250,) (200, 250)
# (200, 250) (200, 250)
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
#animate the simulation (runs if needed)
#test_2d_asym.run(halve_time_res=True) #only saves half the time steps since it is a huge simulation

anim = test_2d_asym.animate(ret=True, focus_on_growth=True, proportionalSpeed=False)
# Out:
# Warning: too many steps for discretization
# breaking because reached max number of layers grown
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
#plt.close()
#save the 2d simulation animation
from matplotlib import animation
from datetime import date

plt.rcParams['animation.ffmpeg_path'] = 'C:/Users/Max-PC/Downloads/ffmpeg-2022-11-03-git-5ccd4d3060-essentials_build/bin/ffmpeg'
print('path found ')
#File management parameters
#Qualifier tag for file names #should include what makes this figure unique
tag = "growht_faceted_attempt" ### NOTE/CAUTION: if you do not change the tag between runs on the same day you will overwrite the previous run: try to use a descriptive tag
todays_date = date.today().strftime("%d-%m-%Y")

#File writer for saving animations as gifs
writergif = animation.PillowWriter(fps=480) 

#optional for saving as mp4, (or anim or mpg) but requires ffmpeg

def progress_printer(current_frame: int, total_frames: int): 
    print(f'Saving frame {current_frame} of {total_frames}')

writervideo = animation.FFMpegWriter(fps=60) #make sure files end in .mp4 oetc.
print('beginning to save...')
anim.save(todays_date+"_2D_"+tag+"_"+str(test_2d_asym.layermax)+"layers.mp4", writer=writervideo, progress_callback=progress_printer)
print('saved!')
# Out:
# path found
# beginning to save...
# Saving frame 0 of 38846
# Saving frame 1 of 38846
# Saving frame 2 of 38846
# Saving frame 3 of 38846
# Saving frame 4 of 38846
# Saving frame 5 of 38846
# Saving frame 6 of 38846
# Saving frame 7 of 38846
# Saving frame 8 of 38846
# Saving frame 9 of 38846
# Saving frame 10 of 38846
# Saving frame 11 of 38846
# Saving frame 12 of 38846
# Saving frame 13 of 38846
# Saving frame 14 of 38846
# Saving frame 15 of 38846
# Saving frame 16 of 38846
# Saving frame 17 of 38846
# Saving frame 18 of 38846
# Saving frame 19 of 38846
# Saving frame 20 of 38846
# Saving frame 21 of 38846
# Saving frame 22 of 38846
# Saving frame 23 of 38846
# Saving frame 24 of 38846
# Saving frame 25 of 38846
# Saving frame 26 of 38846
# Saving frame 27 of 38846
# Saving frame 28 of 38846
# Saving frame 29 of 38846
# Saving frame 30 of 38846
# Saving frame 31 of 38846
# Saving frame 32 of 38846
# Saving frame 33 of 38846
# Saving frame 34 of 38846
# Saving frame 35 of 38846
# Saving frame 36 of 38846
# Saving frame 37 of 38846
# Saving frame 38 of 38846
# Saving frame 39 of 38846
# Saving frame 40 of 38846
# Saving frame 41 of 38846
# Saving frame 42 of 38846
# Saving frame 43 of 38846
# Saving frame 44 of 38846
# Saving frame 45 of 38846
# Saving frame 46 of 38846
# Saving frame 47 of 38846
# Saving frame 48 of 38846
# Saving frame 49 of 38846
# Saving frame 50 of 38846
# Saving frame 51 of 38846
# Saving frame 52 of 38846
# Saving frame 53 of 38846
# Saving frame 54 of 38846
# Saving frame 55 of 38846
# Saving frame 56 of 38846
# Saving frame 57 of 38846
# Saving frame 58 of 38846
# Saving frame 59 of 38846
# Saving frame 60 of 38846
# Saving frame 61 of 38846
# Saving frame 62 of 38846
# Saving frame 63 of 38846
# Saving frame 64 of 38846
# Saving frame 65 of 38846
# Saving frame 66 of 38846
# Saving frame 67 of 38846
# Saving frame 68 of 38846
# Saving frame 69 of 38846
# Saving frame 70 of 38846
# Saving frame 71 of 38846
# Saving frame 72 of 38846
# Saving frame 73 of 38846
# Saving frame 74 of 38846
# Saving frame 75 of 38846
# Saving frame 76 of 38846
# Saving frame 77 of 38846
# Saving frame 78 of 38846
# Saving frame 79 of 38846
# Saving frame 80 of 38846
# Saving frame 81 of 38846
# Saving frame 82 of 38846
# Saving frame 83 of 38846
# Saving frame 84 of 38846
# Saving frame 85 of 38846
# Saving frame 86 of 38846
# Saving frame 87 of 38846
# Saving frame 88 of 38846
# Saving frame 89 of 38846
# Saving frame 90 of 38846
# Saving frame 91 of 38846
# Saving frame 92 of 38846
# Saving frame 93 of 38846
# Saving frame 94 of 38846
# Saving frame 95 of 38846
# Saving frame 96 of 38846
# Saving frame 97 of 38846
# Saving frame 98 of 38846
# Saving frame 99 of 38846
# Saving frame 100 of 38846
# Saving frame 101 of 38846
# Saving frame 102 of 38846
# Saving frame 103 of 38846
# Saving frame 104 of 38846
# Saving frame 105 of 38846
# Saving frame 106 of 38846
# Saving frame 107 of 38846
# Saving frame 108 of 38846
# Saving frame 109 of 38846
# Saving frame 110 of 38846
# Saving frame 111 of 38846
# Saving frame 112 of 38846
# Saving frame 113 of 38846
# Saving frame 114 of 38846
# Saving frame 115 of 38846
# Saving frame 116 of 38846
# Saving frame 117 of 38846
# Saving frame 118 of 38846
# Saving frame 119 of 38846
# Saving frame 120 of 38846
# Saving frame 121 of 38846
# Saving frame 122 of 38846
# Saving frame 123 of 38846
# Saving frame 124 of 38846
# Saving frame 125 of 38846
# Saving frame 126 of 38846
# Saving frame 127 of 38846
# Saving frame 128 of 38846
# Saving frame 129 of 38846
# Saving frame 130 of 38846
# Saving frame 131 of 38846
# Saving frame 132 of 38846
# Saving frame 133 of 38846
# Saving frame 134 of 38846
# Saving frame 135 of 38846
# Saving frame 136 of 38846
# Saving frame 137 of 38846
# Saving frame 138 of 38846
# Saving frame 139 of 38846
# Saving frame 140 of 38846
# Saving frame 141 of 38846
# Saving frame 142 of 38846
# Saving frame 143 of 38846
# Saving frame 144 of 38846
# Saving frame 145 of 38846
# Saving frame 146 of 38846
# Saving frame 147 of 38846
# Saving frame 148 of 38846
# Saving frame 149 of 38846
# Saving frame 150 of 38846
# Saving frame 151 of 38846
# Saving frame 152 of 38846
# Saving frame 153 of 38846
# Saving frame 154 of 38846
# Saving frame 155 of 38846
# Saving frame 156 of 38846
# Saving frame 157 of 38846
# Saving frame 158 of 38846
# Saving frame 159 of 38846
# Saving frame 160 of 38846
# Saving frame 161 of 38846
# Saving frame 162 of 38846
# Saving frame 163 of 38846
# Saving frame 164 of 38846
# Saving frame 165 of 38846
# Saving frame 166 of 38846
# Saving frame 167 of 38846
# Saving frame 168 of 38846
# Saving frame 169 of 38846
# Saving frame 170 of 38846
# Saving frame 171 of 38846
# Saving frame 172 of 38846
# Saving frame 173 of 38846
# Saving frame 174 of 38846
# Saving frame 175 of 38846
# Saving frame 176 of 38846
# Saving frame 177 of 38846
# Saving frame 178 of 38846
# Saving frame 179 of 38846
# Saving frame 180 of 38846
# Saving frame 181 of 38846
# Saving frame 182 of 38846
# Saving frame 183 of 38846
# Saving frame 184 of 38846
# Saving frame 185 of 38846
# Saving frame 186 of 38846
# Saving frame 187 of 38846
# Saving frame 188 of 38846
# Saving frame 189 of 38846
# Saving frame 190 of 38846
# Saving frame 191 of 38846
# Saving frame 192 of 38846
# Saving frame 193 of 38846
# Saving frame 194 of 38846
# Saving frame 195 of 38846
# Saving frame 196 of 38846
# Saving frame 197 of 38846
# Saving frame 198 of 38846
# Saving frame 199 of 38846
# Saving frame 200 of 38846
# Saving frame 201 of 38846
# Saving frame 202 of 38846
# Saving frame 203 of 38846
# Saving frame 204 of 38846
# Saving frame 205 of 38846
# Saving frame 206 of 38846
# Saving frame 207 of 38846
# Saving frame 208 of 38846
# Saving frame 209 of 38846
# Saving frame 210 of 38846
# Saving frame 211 of 38846
# Saving frame 212 of 38846
# Saving frame 213 of 38846
# Saving frame 214 of 38846
# Saving frame 215 of 38846
# Saving frame 216 of 38846
# Saving frame 217 of 38846
# Saving frame 218 of 38846
# Saving frame 219 of 38846
# Saving frame 220 of 38846
# Saving frame 221 of 38846
# Saving frame 222 of 38846
# Saving frame 223 of 38846
# Saving frame 224 of 38846
# Saving frame 225 of 38846
# Saving frame 226 of 38846
# Saving frame 227 of 38846
# Saving frame 228 of 38846
# Saving frame 229 of 38846
# Saving frame 230 of 38846
# Saving frame 231 of 38846
# Saving frame 232 of 38846
# Saving frame 233 of 38846
# Saving frame 234 of 38846
# Saving frame 235 of 38846
# Saving frame 236 of 38846
# Saving frame 237 of 38846
# Saving frame 238 of 38846
# Saving frame 239 of 38846
# Saving frame 240 of 38846
# Saving frame 241 of 38846
# Saving frame 242 of 38846
# Saving frame 243 of 38846
# Saving frame 244 of 38846
# Saving frame 245 of 38846
# Saving frame 246 of 38846
# Saving frame 247 of 38846
# Saving frame 248 of 38846
# Saving frame 249 of 38846
# Saving frame 250 of 38846
# Saving frame 251 of 38846
# Saving frame 252 of 38846
# Saving frame 253 of 38846
# Saving frame 254 of 38846
# Saving frame 255 of 38846
# Saving frame 256 of 38846
# Saving frame 257 of 38846
# Saving frame 258 of 38846
# Saving frame 259 of 38846
# Saving frame 260 of 38846
# Saving frame 261 of 38846
# Saving frame 262 of 38846
# Saving frame 263 of 38846
# Saving frame 264 of 38846
# Saving frame 265 of 38846
# Saving frame 266 of 38846
# Saving frame 267 of 38846
# Saving frame 268 of 38846
# Saving frame 269 of 38846
# Saving frame 270 of 38846
# Saving frame 271 of 38846
# Saving frame 272 of 38846
# Saving frame 273 of 38846
# Saving frame 274 of 38846
# Saving frame 275 of 38846
# Saving frame 276 of 38846
# Saving frame 277 of 38846
# Saving frame 278 of 38846
# Saving frame 279 of 38846
# Saving frame 280 of 38846
# Saving frame 281 of 38846
# Saving frame 282 of 38846
# Saving frame 283 of 38846
# Saving frame 284 of 38846
# Saving frame 285 of 38846
# Saving frame 286 of 38846
# Saving frame 287 of 38846
# Saving frame 288 of 38846
# Saving frame 289 of 38846
# Saving frame 290 of 38846
# Saving frame 291 of 38846
# Saving frame 292 of 38846
# Saving frame 293 of 38846
# Saving frame 294 of 38846
# Saving frame 295 of 38846
# Saving frame 296 of 38846
# Saving frame 297 of 38846
# Saving frame 298 of 38846
# Saving frame 299 of 38846
# Saving frame 300 of 38846
# Saving frame 301 of 38846
# Saving frame 302 of 38846
# Saving frame 303 of 38846
# Saving frame 304 of 38846
# Saving frame 305 of 38846
# Saving frame 306 of 38846
# Saving frame 307 of 38846
# Saving frame 308 of 38846
# Saving frame 309 of 38846
# Saving frame 310 of 38846
# Saving frame 311 of 38846
# Saving frame 312 of 38846
# Saving frame 313 of 38846
# Saving frame 314 of 38846
# Saving frame 315 of 38846
# Saving frame 316 of 38846
# Saving frame 317 of 38846
# Saving frame 318 of 38846
# Saving frame 319 of 38846
# Saving frame 320 of 38846
# Saving frame 321 of 38846
# Saving frame 322 of 38846
# Saving frame 323 of 38846
# Saving frame 324 of 38846
# Saving frame 325 of 38846
# Saving frame 326 of 38846
# Saving frame 327 of 38846
# Saving frame 328 of 38846
# Saving frame 329 of 38846
# Saving frame 330 of 38846
# Saving frame 331 of 38846
# Saving frame 332 of 38846
# Saving frame 333 of 38846
# Saving frame 334 of 38846
# Saving frame 335 of 38846
# Saving frame 336 of 38846
# Saving frame 337 of 38846
# Saving frame 338 of 38846
# Saving frame 339 of 38846
# Saving frame 340 of 38846
# Saving frame 341 of 38846
# Saving frame 342 of 38846
# Saving frame 343 of 38846
# Saving frame 344 of 38846
# Saving frame 345 of 38846
# Saving frame 346 of 38846
# Saving frame 347 of 38846
# Saving frame 348 of 38846
# Saving frame 349 of 38846
# Saving frame 350 of 38846
# Saving frame 351 of 38846
# Saving frame 352 of 38846
# Saving frame 353 of 38846
# Saving frame 354 of 38846
# Saving frame 355 of 38846
# Saving frame 356 of 38846
# Saving frame 357 of 38846
# Saving frame 358 of 38846
# Saving frame 359 of 38846
# Saving frame 360 of 38846
# Saving frame 361 of 38846
# Saving frame 362 of 38846
# Saving frame 363 of 38846
# Saving frame 364 of 38846
# Saving frame 365 of 38846
# Saving frame 366 of 38846
# Saving frame 367 of 38846
# Saving frame 368 of 38846
# Saving frame 369 of 38846
# Saving frame 370 of 38846
# Saving frame 371 of 38846
# Saving frame 372 of 38846
# Saving frame 373 of 38846
# Saving frame 374 of 38846
# Saving frame 375 of 38846
# Saving frame 376 of 38846
# Saving frame 377 of 38846
# Saving frame 378 of 38846
# Saving frame 379 of 38846
# Saving frame 380 of 38846
# Saving frame 381 of 38846
# Saving frame 382 of 38846
# Saving frame 383 of 38846
# Saving frame 384 of 38846
# Saving frame 385 of 38846
# Saving frame 386 of 38846
# Saving frame 387 of 38846
# Saving frame 388 of 38846
# Saving frame 389 of 38846
# Saving frame 390 of 38846
# Saving frame 391 of 38846
# Saving frame 392 of 38846
# Saving frame 393 of 38846
# Saving frame 394 of 38846
# Saving frame 395 of 38846
# Saving frame 396 of 38846
# Saving frame 397 of 38846
# Saving frame 398 of 38846
# Saving frame 399 of 38846
# Saving frame 400 of 38846
# Saving frame 401 of 38846
# Saving frame 402 of 38846
# Saving frame 403 of 38846
# Saving frame 404 of 38846
# Saving frame 405 of 38846
# Saving frame 406 of 38846
# Saving frame 407 of 38846
# Saving frame 408 of 38846
# Saving frame 409 of 38846
# Saving frame 410 of 38846
# Saving frame 411 of 38846
# Saving frame 412 of 38846
# Saving frame 413 of 38846
# Saving frame 414 of 38846
# Saving frame 415 of 38846
# Saving frame 416 of 38846
# Saving frame 417 of 38846
# Saving frame 418 of 38846
# Saving frame 419 of 38846
# Saving frame 420 of 38846
# Saving frame 421 of 38846
# Saving frame 422 of 38846
# Saving frame 423 of 38846
# Saving frame 424 of 38846
# Saving frame 425 of 38846
# Saving frame 426 of 38846
# Saving frame 427 of 38846
# Saving frame 428 of 38846
# Saving frame 429 of 38846
# Saving frame 430 of 38846
# Saving frame 431 of 38846
# Saving frame 432 of 38846
# Saving frame 433 of 38846
# Saving frame 434 of 38846
# Saving frame 435 of 38846
# Saving frame 436 of 38846
# Saving frame 437 of 38846
# Saving frame 438 of 38846
# Saving frame 439 of 38846
# Saving frame 440 of 38846
# Saving frame 441 of 38846
# Saving frame 442 of 38846
# Saving frame 443 of 38846
# Saving frame 444 of 38846
# Saving frame 445 of 38846
# Saving frame 446 of 38846
# Saving frame 447 of 38846
# Saving frame 448 of 38846
# Saving frame 449 of 38846
# Saving frame 450 of 38846
# Saving frame 451 of 38846
# Saving frame 452 of 38846
# Saving frame 453 of 38846
# Saving frame 454 of 38846
# Saving frame 455 of 38846
# Saving frame 456 of 38846
# Saving frame 457 of 38846
# Saving frame 458 of 38846
# Saving frame 459 of 38846
# Saving frame 460 of 38846
# Saving frame 461 of 38846
# Saving frame 462 of 38846
# Saving frame 463 of 38846
# Saving frame 464 of 38846
# Saving frame 465 of 38846
# Saving frame 466 of 38846
# Saving frame 467 of 38846
# Saving frame 468 of 38846
# Saving frame 469 of 38846
# Saving frame 470 of 38846
# Saving frame 471 of 38846
# Saving frame 472 of 38846
# Saving frame 473 of 38846
# Saving frame 474 of 38846
# Saving frame 475 of 38846
# Saving frame 476 of 38846
# Saving frame 477 of 38846
# Saving frame 478 of 38846
# Saving frame 479 of 38846
# Saving frame 480 of 38846
# Saving frame 481 of 38846
# Saving frame 482 of 38846
# Saving frame 483 of 38846
# Saving frame 484 of 38846
# Saving frame 485 of 38846
# Saving frame 486 of 38846
# Saving frame 487 of 38846
# Saving frame 488 of 38846
# Saving frame 489 of 38846
# Saving frame 490 of 38846
# Saving frame 491 of 38846
# Saving frame 492 of 38846
# Saving frame 493 of 38846
# Saving frame 494 of 38846
# Saving frame 495 of 38846
# Saving frame 496 of 38846
# Saving frame 497 of 38846
# Saving frame 498 of 38846
# Saving frame 499 of 38846
# Saving frame 500 of 38846
# Saving frame 501 of 38846
# Saving frame 502 of 38846
# Saving frame 503 of 38846
# Saving frame 504 of 38846
# Saving frame 505 of 38846
# Saving frame 506 of 38846
# Saving frame 507 of 38846
# Saving frame 508 of 38846
# Saving frame 509 of 38846
# Saving frame 510 of 38846
# Saving frame 511 of 38846
# Saving frame 512 of 38846
# Saving frame 513 of 38846
# Saving frame 514 of 38846
# Saving frame 515 of 38846
# Saving frame 516 of 38846
# Saving frame 517 of 38846
# Saving frame 518 of 38846
# Saving frame 519 of 38846
# Saving frame 520 of 38846
# Saving frame 521 of 38846
# Saving frame 522 of 38846
# Saving frame 523 of 38846
# Saving frame 524 of 38846
# Saving frame 525 of 38846
# Saving frame 526 of 38846
# Saving frame 527 of 38846
# Saving frame 528 of 38846
# Saving frame 529 of 38846
# Saving frame 530 of 38846
# Saving frame 531 of 38846
# Saving frame 532 of 38846
# Saving frame 533 of 38846
# Saving frame 534 of 38846
# Saving frame 535 of 38846
# Saving frame 536 of 38846
# Saving frame 537 of 38846
# Saving frame 538 of 38846
# Saving frame 539 of 38846
# Saving frame 540 of 38846
# Saving frame 541 of 38846
# Saving frame 542 of 38846
# Saving frame 543 of 38846
# Saving frame 544 of 38846
# Saving frame 545 of 38846
# Saving frame 546 of 38846
# Saving frame 547 of 38846
# Saving frame 548 of 38846
# Saving frame 549 of 38846
# Saving frame 550 of 38846
# Saving frame 551 of 38846
# Saving frame 552 of 38846
# Saving frame 553 of 38846
# Saving frame 554 of 38846
# Saving frame 555 of 38846
# Saving frame 556 of 38846
# Saving frame 557 of 38846
# Saving frame 558 of 38846
# Saving frame 559 of 38846
# Saving frame 560 of 38846
# Saving frame 561 of 38846
# Saving frame 562 of 38846
# Saving frame 563 of 38846
# Saving frame 564 of 38846
# Saving frame 565 of 38846
# Saving frame 566 of 38846
# Saving frame 567 of 38846
# Saving frame 568 of 38846
# Saving frame 569 of 38846
# Saving frame 570 of 38846
# Saving frame 571 of 38846
# Saving frame 572 of 38846
# Saving frame 573 of 38846
# Saving frame 574 of 38846
# Saving frame 575 of 38846
# Saving frame 576 of 38846
# Saving frame 577 of 38846
# Saving frame 578 of 38846
# Saving frame 579 of 38846
# Saving frame 580 of 38846
# Saving frame 581 of 38846
# Saving frame 582 of 38846
# Saving frame 583 of 38846
# Saving frame 584 of 38846
# Saving frame 585 of 38846
# Saving frame 586 of 38846
# Saving frame 587 of 38846
# Saving frame 588 of 38846
# Saving frame 589 of 38846
# Saving frame 590 of 38846
# Saving frame 591 of 38846
# Saving frame 592 of 38846
# Saving frame 593 of 38846
# Saving frame 594 of 38846
# Saving frame 595 of 38846
# Saving frame 596 of 38846
# Saving frame 597 of 38846
# Saving frame 598 of 38846
# Saving frame 599 of 38846
# Saving frame 600 of 38846
# Saving frame 601 of 38846
# Saving frame 602 of 38846
# Saving frame 603 of 38846
# Saving frame 604 of 38846
# Saving frame 605 of 38846
# Saving frame 606 of 38846
# Saving frame 607 of 38846
# Saving frame 608 of 38846
# Saving frame 609 of 38846
# Saving frame 610 of 38846
# Saving frame 611 of 38846
# Saving frame 612 of 38846
# Saving frame 613 of 38846
# Saving frame 614 of 38846
# Saving frame 615 of 38846
# Saving frame 616 of 38846
# Saving frame 617 of 38846
# Saving frame 618 of 38846
# Saving frame 619 of 38846
# Saving frame 620 of 38846
# Saving frame 621 of 38846
# Saving frame 622 of 38846
# Saving frame 623 of 38846
# Saving frame 624 of 38846
# Saving frame 625 of 38846
# Saving frame 626 of 38846
# Saving frame 627 of 38846
# Saving frame 628 of 38846
# Saving frame 629 of 38846
# Saving frame 630 of 38846
# Saving frame 631 of 38846
# Saving frame 632 of 38846
# Saving frame 633 of 38846
# Saving frame 634 of 38846
# Saving frame 635 of 38846
# Saving frame 636 of 38846
# Saving frame 637 of 38846
# Saving frame 638 of 38846
# Saving frame 639 of 38846
# Saving frame 640 of 38846
# Saving frame 641 of 38846
# Saving frame 642 of 38846
# Saving frame 643 of 38846
# Saving frame 644 of 38846
# Saving frame 645 of 38846
# Saving frame 646 of 38846
# Saving frame 647 of 38846
# Saving frame 648 of 38846
# Saving frame 649 of 38846
# Saving frame 650 of 38846
# Saving frame 651 of 38846
# Saving frame 652 of 38846
# Saving frame 653 of 38846
# Saving frame 654 of 38846
# Saving frame 655 of 38846
# Saving frame 656 of 38846
# Saving frame 657 of 38846
# Saving frame 658 of 38846
# Saving frame 659 of 38846
# Saving frame 660 of 38846
# Saving frame 661 of 38846
# Saving frame 662 of 38846
# Saving frame 663 of 38846
# Saving frame 664 of 38846
# Saving frame 665 of 38846
# Saving frame 666 of 38846
# Saving frame 667 of 38846
# Saving frame 668 of 38846
# Saving frame 669 of 38846
# Saving frame 670 of 38846
# Saving frame 671 of 38846
# Saving frame 672 of 38846
# Saving frame 673 of 38846
# Saving frame 674 of 38846
# Saving frame 675 of 38846
# Saving frame 676 of 38846
# Saving frame 677 of 38846
# Saving frame 678 of 38846
# Saving frame 679 of 38846
# Saving frame 680 of 38846
# Saving frame 681 of 38846
# Saving frame 682 of 38846
# Saving frame 683 of 38846
# Saving frame 684 of 38846
# Saving frame 685 of 38846
# Saving frame 686 of 38846
# Saving frame 687 of 38846
# Saving frame 688 of 38846
# Saving frame 689 of 38846
# Saving frame 690 of 38846
# Saving frame 691 of 38846
# Saving frame 692 of 38846
# Saving frame 693 of 38846
# Saving frame 694 of 38846
# Saving frame 695 of 38846
# Saving frame 696 of 38846
# Saving frame 697 of 38846
# Saving frame 698 of 38846
# Saving frame 699 of 38846
# Saving frame 700 of 38846
# Saving frame 701 of 38846
# Saving frame 702 of 38846
# Saving frame 703 of 38846
# Saving frame 704 of 38846
# Saving frame 705 of 38846
# Saving frame 706 of 38846
# Saving frame 707 of 38846
# Saving frame 708 of 38846
# Saving frame 709 of 38846
# Saving frame 710 of 38846
# Saving frame 711 of 38846
# Saving frame 712 of 38846
# Saving frame 713 of 38846
# Saving frame 714 of 38846
# Saving frame 715 of 38846
# Saving frame 716 of 38846
# Saving frame 717 of 38846
# Saving frame 718 of 38846
# Saving frame 719 of 38846
# Saving frame 720 of 38846
# Saving frame 721 of 38846
# Saving frame 722 of 38846
# Saving frame 723 of 38846
# Saving frame 724 of 38846
# Saving frame 725 of 38846
# Saving frame 726 of 38846
# Saving frame 727 of 38846
# Saving frame 728 of 38846
# Saving frame 729 of 38846
# Saving frame 730 of 38846
# Saving frame 731 of 38846
# Saving frame 732 of 38846
# Saving frame 733 of 38846
# Saving frame 734 of 38846
# Saving frame 735 of 38846
# Saving frame 736 of 38846
# Saving frame 737 of 38846
# Saving frame 738 of 38846
# Saving frame 739 of 38846
# Saving frame 740 of 38846
# Saving frame 741 of 38846
# Saving frame 742 of 38846
# Saving frame 743 of 38846
# Saving frame 744 of 38846
# Saving frame 745 of 38846
# Saving frame 746 of 38846
# Saving frame 747 of 38846
# Saving frame 748 of 38846
# Saving frame 749 of 38846
# Saving frame 750 of 38846
# Saving frame 751 of 38846
# Saving frame 752 of 38846
# Saving frame 753 of 38846
# Saving frame 754 of 38846
# Saving frame 755 of 38846
# Saving frame 756 of 38846
# Saving frame 757 of 38846
# Saving frame 758 of 38846
# Saving frame 759 of 38846
# Saving frame 760 of 38846
# Saving frame 761 of 38846
# Saving frame 762 of 38846
# Saving frame 763 of 38846
# Saving frame 764 of 38846
# Saving frame 765 of 38846
# Saving frame 766 of 38846
# Saving frame 767 of 38846
# Saving frame 768 of 38846
# Saving frame 769 of 38846
# Saving frame 770 of 38846
# Saving frame 771 of 38846
# Saving frame 772 of 38846
# Saving frame 773 of 38846
# Saving frame 774 of 38846
# Saving frame 775 of 38846
# Saving frame 776 of 38846
# Saving frame 777 of 38846
# Saving frame 778 of 38846
# Saving frame 779 of 38846
# Saving frame 780 of 38846
# Saving frame 781 of 38846
# Saving frame 782 of 38846
# Saving frame 783 of 38846
# Saving frame 784 of 38846
# Saving frame 785 of 38846
# Saving frame 786 of 38846
# Saving frame 787 of 38846
# Saving frame 788 of 38846
# Saving frame 789 of 38846
# Saving frame 790 of 38846
# Saving frame 791 of 38846
# Saving frame 792 of 38846
# Saving frame 793 of 38846
# Saving frame 794 of 38846
# Saving frame 795 of 38846
# Saving frame 796 of 38846
# Saving frame 797 of 38846
# Saving frame 798 of 38846
# Saving frame 799 of 38846
# Saving frame 800 of 38846
# Saving frame 801 of 38846
# Saving frame 802 of 38846
# Saving frame 803 of 38846
# Saving frame 804 of 38846
# Saving frame 805 of 38846
# Saving frame 806 of 38846
# Saving frame 807 of 38846
# Saving frame 808 of 38846
# Saving frame 809 of 38846
# Saving frame 810 of 38846
# Saving frame 811 of 38846
# Saving frame 812 of 38846
# Saving frame 813 of 38846
# Saving frame 814 of 38846
# Saving frame 815 of 38846
# Saving frame 816 of 38846
# Saving frame 817 of 38846
# Saving frame 818 of 38846
# Saving frame 819 of 38846
# Saving frame 820 of 38846
# Saving frame 821 of 38846
# Saving frame 822 of 38846
# Saving frame 823 of 38846
# Saving frame 824 of 38846
# Saving frame 825 of 38846
# Saving frame 826 of 38846
# Saving frame 827 of 38846
# Saving frame 828 of 38846
# Saving frame 829 of 38846
# Saving frame 830 of 38846
# Saving frame 831 of 38846
# Saving frame 832 of 38846
# Saving frame 833 of 38846
# Saving frame 834 of 38846
# Saving frame 835 of 38846
# Saving frame 836 of 38846
# Saving frame 837 of 38846
# Saving frame 838 of 38846
# Saving frame 839 of 38846
# Saving frame 840 of 38846
# Saving frame 841 of 38846
# Saving frame 842 of 38846
# Saving frame 843 of 38846
# Saving frame 844 of 38846
# Saving frame 845 of 38846
# Saving frame 846 of 38846
# Saving frame 847 of 38846
# Saving frame 848 of 38846
# Saving frame 849 of 38846
# Saving frame 850 of 38846
# Saving frame 851 of 38846
# Saving frame 852 of 38846
# Saving frame 853 of 38846
# Saving frame 854 of 38846
# Saving frame 855 of 38846
# Saving frame 856 of 38846
# Saving frame 857 of 38846
# Saving frame 858 of 38846
# Saving frame 859 of 38846
# Saving frame 860 of 38846
# Saving frame 861 of 38846
# Saving frame 862 of 38846
# Saving frame 863 of 38846
# Saving frame 864 of 38846
# Saving frame 865 of 38846
# Saving frame 866 of 38846
# Saving frame 867 of 38846
# Saving frame 868 of 38846
# Saving frame 869 of 38846
# Saving frame 870 of 38846
# Saving frame 871 of 38846
# Saving frame 872 of 38846
# Saving frame 873 of 38846
# Saving frame 874 of 38846
# Saving frame 875 of 38846
# Saving frame 876 of 38846
# Saving frame 877 of 38846
# Saving frame 878 of 38846
# Saving frame 879 of 38846
# Saving frame 880 of 38846
# Saving frame 881 of 38846
# Saving frame 882 of 38846
# Saving frame 883 of 38846
# Saving frame 884 of 38846
# Saving frame 885 of 38846
# Saving frame 886 of 38846
# Saving frame 887 of 38846
# Saving frame 888 of 38846
# Saving frame 889 of 38846
# Saving frame 890 of 38846
# Saving frame 891 of 38846
# Saving frame 892 of 38846
# Saving frame 893 of 38846
# Saving frame 894 of 38846
# Saving frame 895 of 38846
# Saving frame 896 of 38846
# Saving frame 897 of 38846
# Saving frame 898 of 38846
# Saving frame 899 of 38846
# Saving frame 900 of 38846
# Saving frame 901 of 38846
# Saving frame 902 of 38846
# Saving frame 903 of 38846
# Saving frame 904 of 38846
# Saving frame 905 of 38846
# Saving frame 906 of 38846
# Saving frame 907 of 38846
# Saving frame 908 of 38846
# Saving frame 909 of 38846
# Saving frame 910 of 38846
# Saving frame 911 of 38846
# Saving frame 912 of 38846
# Saving frame 913 of 38846
# Saving frame 914 of 38846
# Saving frame 915 of 38846
# Saving frame 916 of 38846
# Saving frame 917 of 38846
# Saving frame 918 of 38846
# Saving frame 919 of 38846
# Saving frame 920 of 38846
# Saving frame 921 of 38846
# Saving frame 922 of 38846
# Saving frame 923 of 38846
# Saving frame 924 of 38846
# Saving frame 925 of 38846
# Saving frame 926 of 38846
# Saving frame 927 of 38846
# Saving frame 928 of 38846
# Saving frame 929 of 38846
# Saving frame 930 of 38846
# Saving frame 931 of 38846
# Saving frame 932 of 38846
# Saving frame 933 of 38846
# Saving frame 934 of 38846
# Saving frame 935 of 38846
# Saving frame 936 of 38846
# Saving frame 937 of 38846
# Saving frame 938 of 38846
# Saving frame 939 of 38846
# Saving frame 940 of 38846
# Saving frame 941 of 38846
# Saving frame 942 of 38846
# Saving frame 943 of 38846
# Saving frame 944 of 38846
# Saving frame 945 of 38846
# Saving frame 946 of 38846
# Saving frame 947 of 38846
# Saving frame 948 of 38846
# Saving frame 949 of 38846
# Saving frame 950 of 38846
# Saving frame 951 of 38846
# Saving frame 952 of 38846
# Saving frame 953 of 38846
# Saving frame 954 of 38846
# Saving frame 955 of 38846
# Saving frame 956 of 38846
# Saving frame 957 of 38846
# Saving frame 958 of 38846
# Saving frame 959 of 38846
# Saving frame 960 of 38846
# Saving frame 961 of 38846
# Saving frame 962 of 38846
# Saving frame 963 of 38846
# Saving frame 964 of 38846
# Saving frame 965 of 38846
# Saving frame 966 of 38846
# Saving frame 967 of 38846
# Saving frame 968 of 38846
# Saving frame 969 of 38846
# Saving frame 970 of 38846
# Saving frame 971 of 38846
# Saving frame 972 of 38846
# Saving frame 973 of 38846
# Saving frame 974 of 38846
# Saving frame 975 of 38846
# Saving frame 976 of 38846
# Saving frame 977 of 38846
# Saving frame 978 of 38846
# Saving frame 979 of 38846
# Saving frame 980 of 38846
# Saving frame 981 of 38846
# Saving frame 982 of 38846
# Saving frame 983 of 38846
# Saving frame 984 of 38846
# Saving frame 985 of 38846
# Saving frame 986 of 38846
# Saving frame 987 of 38846
# Saving frame 988 of 38846
# Saving frame 989 of 38846
# Saving frame 990 of 38846
# Saving frame 991 of 38846
# Saving frame 992 of 38846
# Saving frame 993 of 38846
# Saving frame 994 of 38846
# Saving frame 995 of 38846
# Saving frame 996 of 38846
# Saving frame 997 of 38846
# Saving frame 998 of 38846
# Saving frame 999 of 38846
# Saving frame 1000 of 38846
# Saving frame 1001 of 38846
# Saving frame 1002 of 38846
# Saving frame 1003 of 38846
# Saving frame 1004 of 38846
# Saving frame 1005 of 38846
# Saving frame 1006 of 38846
# Saving frame 1007 of 38846
# Saving frame 1008 of 38846
# Saving frame 1009 of 38846
# Saving frame 1010 of 38846
# Saving frame 1011 of 38846
# Saving frame 1012 of 38846
# Saving frame 1013 of 38846
# Saving frame 1014 of 38846
# Saving frame 1015 of 38846
# Saving frame 1016 of 38846
# Saving frame 1017 of 38846
# Saving frame 1018 of 38846
# Saving frame 1019 of 38846
# Saving frame 1020 of 38846
# Saving frame 1021 of 38846
# Saving frame 1022 of 38846
# Saving frame 1023 of 38846
# Saving frame 1024 of 38846
# Saving frame 1025 of 38846
# Saving frame 1026 of 38846
# Saving frame 1027 of 38846
# Saving frame 1028 of 38846
# Saving frame 1029 of 38846
# Saving frame 1030 of 38846
# Saving frame 1031 of 38846
# Saving frame 1032 of 38846
# Saving frame 1033 of 38846
# Saving frame 1034 of 38846
# Saving frame 1035 of 38846
# Saving frame 1036 of 38846
# Saving frame 1037 of 38846
# Saving frame 1038 of 38846
# Saving frame 1039 of 38846
# Saving frame 1040 of 38846
# Saving frame 1041 of 38846
# Saving frame 1042 of 38846
# Saving frame 1043 of 38846
# Saving frame 1044 of 38846
# Saving frame 1045 of 38846
# Saving frame 1046 of 38846
# Saving frame 1047 of 38846
# Saving frame 1048 of 38846
# Saving frame 1049 of 38846
# Saving frame 1050 of 38846
# Saving frame 1051 of 38846
# Saving frame 1052 of 38846
# Saving frame 1053 of 38846
# Saving frame 1054 of 38846
# Saving frame 1055 of 38846
# Saving frame 1056 of 38846
# Saving frame 1057 of 38846
# Saving frame 1058 of 38846
# Saving frame 1059 of 38846
# Saving frame 1060 of 38846
# Saving frame 1061 of 38846
# Saving frame 1062 of 38846
# Saving frame 1063 of 38846
# Saving frame 1064 of 38846
# Saving frame 1065 of 38846
# Saving frame 1066 of 38846
# Saving frame 1067 of 38846
# Saving frame 1068 of 38846
# Saving frame 1069 of 38846
# Saving frame 1070 of 38846
# Saving frame 1071 of 38846
# Saving frame 1072 of 38846
# Saving frame 1073 of 38846
# Saving frame 1074 of 38846
# Saving frame 1075 of 38846
# Saving frame 1076 of 38846
# Saving frame 1077 of 38846
# Saving frame 1078 of 38846
# Saving frame 1079 of 38846
# Saving frame 1080 of 38846
# Saving frame 1081 of 38846
# Saving frame 1082 of 38846
# Saving frame 1083 of 38846
# Saving frame 1084 of 38846
# Saving frame 1085 of 38846
# Saving frame 1086 of 38846
# Saving frame 1087 of 38846
# Saving frame 1088 of 38846
# Saving frame 1089 of 38846
# Saving frame 1090 of 38846
# Saving frame 1091 of 38846
# Saving frame 1092 of 38846
# Saving frame 1093 of 38846
# Saving frame 1094 of 38846
# Saving frame 1095 of 38846
# Saving frame 1096 of 38846
# Saving frame 1097 of 38846
# Saving frame 1098 of 38846
# Saving frame 1099 of 38846
# Saving frame 1100 of 38846
# Saving frame 1101 of 38846
# Saving frame 1102 of 38846
# Saving frame 1103 of 38846
# Saving frame 1104 of 38846
# Saving frame 1105 of 38846
# Saving frame 1106 of 38846
# Saving frame 1107 of 38846
# Saving frame 1108 of 38846
# Saving frame 1109 of 38846
# Saving frame 1110 of 38846
# Saving frame 1111 of 38846
# Saving frame 1112 of 38846
# Saving frame 1113 of 38846
# Saving frame 1114 of 38846
# Saving frame 1115 of 38846
# Saving frame 1116 of 38846
# Saving frame 1117 of 38846
# Saving frame 1118 of 38846
# Saving frame 1119 of 38846
# Saving frame 1120 of 38846
# Saving frame 1121 of 38846
# Saving frame 1122 of 38846
# Saving frame 1123 of 38846
# Saving frame 1124 of 38846
# Saving frame 1125 of 38846
# Saving frame 1126 of 38846
# Saving frame 1127 of 38846
# Saving frame 1128 of 38846
# Saving frame 1129 of 38846
# Saving frame 1130 of 38846
# Saving frame 1131 of 38846
# Saving frame 1132 of 38846
# Saving frame 1133 of 38846
# Saving frame 1134 of 38846
# Saving frame 1135 of 38846
# Saving frame 1136 of 38846
# Saving frame 1137 of 38846
# Saving frame 1138 of 38846
# Saving frame 1139 of 38846
# Saving frame 1140 of 38846
# Saving frame 1141 of 38846
# Saving frame 1142 of 38846
# Saving frame 1143 of 38846
# Saving frame 1144 of 38846
# Saving frame 1145 of 38846
# Saving frame 1146 of 38846
# Saving frame 1147 of 38846
# Saving frame 1148 of 38846
# Saving frame 1149 of 38846
# Saving frame 1150 of 38846
# Saving frame 1151 of 38846
# Saving frame 1152 of 38846
# Saving frame 1153 of 38846
# Saving frame 1154 of 38846
# Saving frame 1155 of 38846
# Saving frame 1156 of 38846
# Saving frame 1157 of 38846
# Saving frame 1158 of 38846
# Saving frame 1159 of 38846
# Saving frame 1160 of 38846
# Saving frame 1161 of 38846
# Saving frame 1162 of 38846
# Saving frame 1163 of 38846
# Saving frame 1164 of 38846
# Saving frame 1165 of 38846
# Saving frame 1166 of 38846
# Saving frame 1167 of 38846
# Saving frame 1168 of 38846
# Saving frame 1169 of 38846
# Saving frame 1170 of 38846
# Saving frame 1171 of 38846
# Saving frame 1172 of 38846
# Saving frame 1173 of 38846
# Saving frame 1174 of 38846
# Saving frame 1175 of 38846
# Saving frame 1176 of 38846
# Saving frame 1177 of 38846
# Saving frame 1178 of 38846
# Saving frame 1179 of 38846
# Saving frame 1180 of 38846
# Saving frame 1181 of 38846
# Saving frame 1182 of 38846
# Saving frame 1183 of 38846
# Saving frame 1184 of 38846
# Saving frame 1185 of 38846
# Saving frame 1186 of 38846
# Saving frame 1187 of 38846
# Saving frame 1188 of 38846
# Saving frame 1189 of 38846
# Saving frame 1190 of 38846
# Saving frame 1191 of 38846
# Saving frame 1192 of 38846
# Saving frame 1193 of 38846
# Saving frame 1194 of 38846
# Saving frame 1195 of 38846
# Saving frame 1196 of 38846
# Saving frame 1197 of 38846
# Saving frame 1198 of 38846
# Saving frame 1199 of 38846
# Saving frame 1200 of 38846
# Saving frame 1201 of 38846
# Saving frame 1202 of 38846
# Saving frame 1203 of 38846
# Saving frame 1204 of 38846
# Saving frame 1205 of 38846
# Saving frame 1206 of 38846
# Saving frame 1207 of 38846
# Saving frame 1208 of 38846
# Saving frame 1209 of 38846
# Saving frame 1210 of 38846
# Saving frame 1211 of 38846
# Saving frame 1212 of 38846
# Saving frame 1213 of 38846
# Saving frame 1214 of 38846
# Saving frame 1215 of 38846
# Saving frame 1216 of 38846
# Saving frame 1217 of 38846
# Saving frame 1218 of 38846
# Saving frame 1219 of 38846
# Saving frame 1220 of 38846
# Saving frame 1221 of 38846
# Saving frame 1222 of 38846
# Saving frame 1223 of 38846
# Saving frame 1224 of 38846
# Saving frame 1225 of 38846
# Saving frame 1226 of 38846
# Saving frame 1227 of 38846
# Saving frame 1228 of 38846
# Saving frame 1229 of 38846
# Saving frame 1230 of 38846
# Saving frame 1231 of 38846
# Saving frame 1232 of 38846
# Saving frame 1233 of 38846
# Saving frame 1234 of 38846
# Saving frame 1235 of 38846
# Saving frame 1236 of 38846
# Saving frame 1237 of 38846
# Saving frame 1238 of 38846
# Saving frame 1239 of 38846
# Saving frame 1240 of 38846
# Saving frame 1241 of 38846
# Saving frame 1242 of 38846
# Saving frame 1243 of 38846
# Saving frame 1244 of 38846
# Saving frame 1245 of 38846
# Saving frame 1246 of 38846
# Saving frame 1247 of 38846
# Saving frame 1248 of 38846
# Saving frame 1249 of 38846
# Saving frame 1250 of 38846
# Saving frame 1251 of 38846
# Saving frame 1252 of 38846
# Saving frame 1253 of 38846
# Saving frame 1254 of 38846
# Saving frame 1255 of 38846
# Saving frame 1256 of 38846
# Saving frame 1257 of 38846
# Saving frame 1258 of 38846
# Saving frame 1259 of 38846
# Saving frame 1260 of 38846
# Saving frame 1261 of 38846
# Saving frame 1262 of 38846
# Saving frame 1263 of 38846
# Saving frame 1264 of 38846
# Saving frame 1265 of 38846
# Saving frame 1266 of 38846
# Saving frame 1267 of 38846
# Saving frame 1268 of 38846
# Saving frame 1269 of 38846
# Saving frame 1270 of 38846
# Saving frame 1271 of 38846
# Saving frame 1272 of 38846
# Saving frame 1273 of 38846
# Saving frame 1274 of 38846
# Saving frame 1275 of 38846
# Saving frame 1276 of 38846
# Saving frame 1277 of 38846
# Saving frame 1278 of 38846
# Saving frame 1279 of 38846
# Saving frame 1280 of 38846
# Saving frame 1281 of 38846
# Saving frame 1282 of 38846
# Saving frame 1283 of 38846
# Saving frame 1284 of 38846
# Saving frame 1285 of 38846
# Saving frame 1286 of 38846
# Saving frame 1287 of 38846
# Saving frame 1288 of 38846
# Saving frame 1289 of 38846
# Saving frame 1290 of 38846
# Saving frame 1291 of 38846
# Saving frame 1292 of 38846
# Saving frame 1293 of 38846
# Saving frame 1294 of 38846
# Saving frame 1295 of 38846
# Saving frame 1296 of 38846
# Saving frame 1297 of 38846
# Saving frame 1298 of 38846
# Saving frame 1299 of 38846
# Saving frame 1300 of 38846
# Saving frame 1301 of 38846
# Saving frame 1302 of 38846
# Saving frame 1303 of 38846
# Saving frame 1304 of 38846
# Saving frame 1305 of 38846
# Saving frame 1306 of 38846
# Saving frame 1307 of 38846
# Saving frame 1308 of 38846
# Saving frame 1309 of 38846
# Saving frame 1310 of 38846
# Saving frame 1311 of 38846
# Saving frame 1312 of 38846
# Saving frame 1313 of 38846
# Saving frame 1314 of 38846
# Saving frame 1315 of 38846
# Saving frame 1316 of 38846
# Saving frame 1317 of 38846
# Saving frame 1318 of 38846
# Saving frame 1319 of 38846
# Saving frame 1320 of 38846
# Saving frame 1321 of 38846
# Saving frame 1322 of 38846
# Saving frame 1323 of 38846
# Saving frame 1324 of 38846
# Saving frame 1325 of 38846
# Saving frame 1326 of 38846
# Saving frame 1327 of 38846
# Saving frame 1328 of 38846
# Saving frame 1329 of 38846
# Saving frame 1330 of 38846
# Saving frame 1331 of 38846
# Saving frame 1332 of 38846
# Saving frame 1333 of 38846
# Saving frame 1334 of 38846
# Saving frame 1335 of 38846
# Saving frame 1336 of 38846
# Saving frame 1337 of 38846
# Saving frame 1338 of 38846
# Saving frame 1339 of 38846
# Saving frame 1340 of 38846
# Saving frame 1341 of 38846
# Saving frame 1342 of 38846
# Saving frame 1343 of 38846
# Saving frame 1344 of 38846
# Saving frame 1345 of 38846
# Saving frame 1346 of 38846
# Saving frame 1347 of 38846
# Saving frame 1348 of 38846
# Saving frame 1349 of 38846
# Saving frame 1350 of 38846
# Saving frame 1351 of 38846
# Saving frame 1352 of 38846
# Saving frame 1353 of 38846
# Saving frame 1354 of 38846
# Saving frame 1355 of 38846
# Saving frame 1356 of 38846
# Saving frame 1357 of 38846
# Saving frame 1358 of 38846
# Saving frame 1359 of 38846
# Saving frame 1360 of 38846
# Saving frame 1361 of 38846
# Saving frame 1362 of 38846
# Saving frame 1363 of 38846
# Saving frame 1364 of 38846
# Saving frame 1365 of 38846
# Saving frame 1366 of 38846
# Saving frame 1367 of 38846
# Saving frame 1368 of 38846
# Saving frame 1369 of 38846
# Saving frame 1370 of 38846
# Saving frame 1371 of 38846
# Saving frame 1372 of 38846
# Saving frame 1373 of 38846
# Saving frame 1374 of 38846
# Saving frame 1375 of 38846
# Saving frame 1376 of 38846
# Saving frame 1377 of 38846
# Saving frame 1378 of 38846
# Saving frame 1379 of 38846
# Saving frame 1380 of 38846
# Saving frame 1381 of 38846
# Saving frame 1382 of 38846
# Saving frame 1383 of 38846
# Saving frame 1384 of 38846
# Saving frame 1385 of 38846
# Saving frame 1386 of 38846
# Saving frame 1387 of 38846
# Saving frame 1388 of 38846
# Saving frame 1389 of 38846
# Saving frame 1390 of 38846
# Saving frame 1391 of 38846
# Saving frame 1392 of 38846
# Saving frame 1393 of 38846
# Saving frame 1394 of 38846
# Saving frame 1395 of 38846
# Saving frame 1396 of 38846
# Saving frame 1397 of 38846
# Saving frame 1398 of 38846
# Saving frame 1399 of 38846
# Saving frame 1400 of 38846
# Saving frame 1401 of 38846
# Saving frame 1402 of 38846
# Saving frame 1403 of 38846
# Saving frame 1404 of 38846
# Saving frame 1405 of 38846
# Saving frame 1406 of 38846
# Saving frame 1407 of 38846
# Saving frame 1408 of 38846
# Saving frame 1409 of 38846
# Saving frame 1410 of 38846
# Saving frame 1411 of 38846
# Saving frame 1412 of 38846
# Saving frame 1413 of 38846
# Saving frame 1414 of 38846
# Saving frame 1415 of 38846
# Saving frame 1416 of 38846
# Saving frame 1417 of 38846
# Saving frame 1418 of 38846
# Saving frame 1419 of 38846
# Saving frame 1420 of 38846
# Saving frame 1421 of 38846
# Saving frame 1422 of 38846
# Saving frame 1423 of 38846
# Saving frame 1424 of 38846
# Saving frame 1425 of 38846
# Saving frame 1426 of 38846
# Saving frame 1427 of 38846
# Saving frame 1428 of 38846
# Saving frame 1429 of 38846
# Saving frame 1430 of 38846
# Saving frame 1431 of 38846
# Saving frame 1432 of 38846
# Saving frame 1433 of 38846
# Saving frame 1434 of 38846
# Saving frame 1435 of 38846
# Saving frame 1436 of 38846
# Saving frame 1437 of 38846
# Saving frame 1438 of 38846
# Saving frame 1439 of 38846
# Saving frame 1440 of 38846
# Saving frame 1441 of 38846
# Saving frame 1442 of 38846
# Saving frame 1443 of 38846
# Saving frame 1444 of 38846
# Saving frame 1445 of 38846
# Saving frame 1446 of 38846
# Saving frame 1447 of 38846
# Saving frame 1448 of 38846
# Saving frame 1449 of 38846
# Saving frame 1450 of 38846
# Saving frame 1451 of 38846
# Saving frame 1452 of 38846
# Saving frame 1453 of 38846
# Saving frame 1454 of 38846
# Saving frame 1455 of 38846
# Saving frame 1456 of 38846
# Saving frame 1457 of 38846
# Saving frame 1458 of 38846
# Saving frame 1459 of 38846
# Saving frame 1460 of 38846
# Saving frame 1461 of 38846
# Saving frame 1462 of 38846
# Saving frame 1463 of 38846
# Saving frame 1464 of 38846
# Saving frame 1465 of 38846
# Saving frame 1466 of 38846
# Saving frame 1467 of 38846
# Saving frame 1468 of 38846
# Saving frame 1469 of 38846
# Saving frame 1470 of 38846
# Saving frame 1471 of 38846
# Saving frame 1472 of 38846
# Saving frame 1473 of 38846
# Saving frame 1474 of 38846
# Saving frame 1475 of 38846
# Saving frame 1476 of 38846
# Saving frame 1477 of 38846
# Saving frame 1478 of 38846
# Saving frame 1479 of 38846
# Saving frame 1480 of 38846
# Saving frame 1481 of 38846
# Saving frame 1482 of 38846
# Saving frame 1483 of 38846
# Saving frame 1484 of 38846
# Saving frame 1485 of 38846
# Saving frame 1486 of 38846
# Saving frame 1487 of 38846
# Saving frame 1488 of 38846
# Saving frame 1489 of 38846
# Saving frame 1490 of 38846
# Saving frame 1491 of 38846
# Saving frame 1492 of 38846
# Saving frame 1493 of 38846
# Saving frame 1494 of 38846
# Saving frame 1495 of 38846
# Saving frame 1496 of 38846
# Saving frame 1497 of 38846
# Saving frame 1498 of 38846
# Saving frame 1499 of 38846
# Saving frame 1500 of 38846
# Saving frame 1501 of 38846
# Saving frame 1502 of 38846
# Saving frame 1503 of 38846
# Saving frame 1504 of 38846
# Saving frame 1505 of 38846
# Saving frame 1506 of 38846
# Saving frame 1507 of 38846
# Saving frame 1508 of 38846
# Saving frame 1509 of 38846
# Saving frame 1510 of 38846
# Saving frame 1511 of 38846
# Saving frame 1512 of 38846
# Saving frame 1513 of 38846
# Saving frame 1514 of 38846
# Saving frame 1515 of 38846
# Saving frame 1516 of 38846
# Saving frame 1517 of 38846
# Saving frame 1518 of 38846
# Saving frame 1519 of 38846
# Saving frame 1520 of 38846
# Saving frame 1521 of 38846
# Saving frame 1522 of 38846
# Saving frame 1523 of 38846
# Saving frame 1524 of 38846
# Saving frame 1525 of 38846
# Saving frame 1526 of 38846
# Saving frame 1527 of 38846
# Saving frame 1528 of 38846
# Saving frame 1529 of 38846
# Saving frame 1530 of 38846
# Saving frame 1531 of 38846
# Saving frame 1532 of 38846
# Saving frame 1533 of 38846
# Saving frame 1534 of 38846
# Saving frame 1535 of 38846
# Saving frame 1536 of 38846
# Saving frame 1537 of 38846
# Saving frame 1538 of 38846
# Saving frame 1539 of 38846
# Saving frame 1540 of 38846
# Saving frame 1541 of 38846
# Saving frame 1542 of 38846
# Saving frame 1543 of 38846
# Saving frame 1544 of 38846
# Saving frame 1545 of 38846
# Saving frame 1546 of 38846
# Saving frame 1547 of 38846
# Saving frame 1548 of 38846
# Saving frame 1549 of 38846
# Saving frame 1550 of 38846
# Saving frame 1551 of 38846
# Saving frame 1552 of 38846
# Saving frame 1553 of 38846
# Saving frame 1554 of 38846
# Saving frame 1555 of 38846
# Saving frame 1556 of 38846
# Saving frame 1557 of 38846
# Saving frame 1558 of 38846
# Saving frame 1559 of 38846
# Saving frame 1560 of 38846
# Saving frame 1561 of 38846
# Saving frame 1562 of 38846
# Saving frame 1563 of 38846
# Saving frame 1564 of 38846
# Saving frame 1565 of 38846
# Saving frame 1566 of 38846
# Saving frame 1567 of 38846
# Saving frame 1568 of 38846
# Saving frame 1569 of 38846
# Saving frame 1570 of 38846
# Saving frame 1571 of 38846
# Saving frame 1572 of 38846
# Saving frame 1573 of 38846
# Saving frame 1574 of 38846
# Saving frame 1575 of 38846
# Saving frame 1576 of 38846
# Saving frame 1577 of 38846
# Saving frame 1578 of 38846
# Saving frame 1579 of 38846
# Saving frame 1580 of 38846
# Saving frame 1581 of 38846
# Saving frame 1582 of 38846
# Saving frame 1583 of 38846
# Saving frame 1584 of 38846
# Saving frame 1585 of 38846
# Saving frame 1586 of 38846
# Saving frame 1587 of 38846
# Saving frame 1588 of 38846
# Saving frame 1589 of 38846
# Saving frame 1590 of 38846
# Saving frame 1591 of 38846
# Saving frame 1592 of 38846
# Saving frame 1593 of 38846
# Saving frame 1594 of 38846
# Saving frame 1595 of 38846
# Saving frame 1596 of 38846
# Saving frame 1597 of 38846
# Saving frame 1598 of 38846
# Saving frame 1599 of 38846
# Saving frame 1600 of 38846
# Saving frame 1601 of 38846
# Saving frame 1602 of 38846
# Saving frame 1603 of 38846
# Saving frame 1604 of 38846
# Saving frame 1605 of 38846
# Saving frame 1606 of 38846
# Saving frame 1607 of 38846
# Saving frame 1608 of 38846
# Saving frame 1609 of 38846
# Saving frame 1610 of 38846
# Saving frame 1611 of 38846
# Saving frame 1612 of 38846
# Saving frame 1613 of 38846
# Saving frame 1614 of 38846
# Saving frame 1615 of 38846
# Saving frame 1616 of 38846
# Saving frame 1617 of 38846
# Saving frame 1618 of 38846
# Saving frame 1619 of 38846
# Saving frame 1620 of 38846
# Saving frame 1621 of 38846
# Saving frame 1622 of 38846
# Saving frame 1623 of 38846
# Saving frame 1624 of 38846
# Saving frame 1625 of 38846
# Saving frame 1626 of 38846
# Saving frame 1627 of 38846
# Saving frame 1628 of 38846
# Saving frame 1629 of 38846
# Saving frame 1630 of 38846
# Saving frame 1631 of 38846
# Saving frame 1632 of 38846
# Saving frame 1633 of 38846
# Saving frame 1634 of 38846
# Saving frame 1635 of 38846
# Saving frame 1636 of 38846
# Saving frame 1637 of 38846
# Saving frame 1638 of 38846
# Saving frame 1639 of 38846
# Saving frame 1640 of 38846
# Saving frame 1641 of 38846
# Saving frame 1642 of 38846
# Saving frame 1643 of 38846
# Saving frame 1644 of 38846
# Saving frame 1645 of 38846
# Saving frame 1646 of 38846
# Saving frame 1647 of 38846
# Saving frame 1648 of 38846
# Saving frame 1649 of 38846
# Saving frame 1650 of 38846
# Saving frame 1651 of 38846
# Saving frame 1652 of 38846
# Saving frame 1653 of 38846
# Saving frame 1654 of 38846
# Saving frame 1655 of 38846
# Saving frame 1656 of 38846
# Saving frame 1657 of 38846
# Saving frame 1658 of 38846
# Saving frame 1659 of 38846
# Saving frame 1660 of 38846
# Saving frame 1661 of 38846
# Saving frame 1662 of 38846
# Saving frame 1663 of 38846
# Saving frame 1664 of 38846
# Saving frame 1665 of 38846
# Saving frame 1666 of 38846
# Saving frame 1667 of 38846
# Saving frame 1668 of 38846
# Saving frame 1669 of 38846
# Saving frame 1670 of 38846
# Saving frame 1671 of 38846
# Saving frame 1672 of 38846
# Saving frame 1673 of 38846
# Saving frame 1674 of 38846
# Saving frame 1675 of 38846
# Saving frame 1676 of 38846
# Saving frame 1677 of 38846
# Saving frame 1678 of 38846
# Saving frame 1679 of 38846
# Saving frame 1680 of 38846
# Saving frame 1681 of 38846
# Saving frame 1682 of 38846
# Saving frame 1683 of 38846
# Saving frame 1684 of 38846
# Saving frame 1685 of 38846
# Saving frame 1686 of 38846
# Saving frame 1687 of 38846
# Saving frame 1688 of 38846
# Saving frame 1689 of 38846
# Saving frame 1690 of 38846
# Saving frame 1691 of 38846
# Saving frame 1692 of 38846
# Saving frame 1693 of 38846
# Saving frame 1694 of 38846
# Saving frame 1695 of 38846
# Saving frame 1696 of 38846
# Saving frame 1697 of 38846
# Saving frame 1698 of 38846
# Saving frame 1699 of 38846
# Saving frame 1700 of 38846
# Saving frame 1701 of 38846
# Saving frame 1702 of 38846
# Saving frame 1703 of 38846
# Saving frame 1704 of 38846
# Saving frame 1705 of 38846
# Saving frame 1706 of 38846
# Saving frame 1707 of 38846
# Saving frame 1708 of 38846
# Saving frame 1709 of 38846
# Saving frame 1710 of 38846
# Saving frame 1711 of 38846
# Saving frame 1712 of 38846
# Saving frame 1713 of 38846
# Saving frame 1714 of 38846
# Saving frame 1715 of 38846
# Saving frame 1716 of 38846
# Saving frame 1717 of 38846
# Saving frame 1718 of 38846
# Saving frame 1719 of 38846
# Saving frame 1720 of 38846
# Saving frame 1721 of 38846
# Saving frame 1722 of 38846
# Saving frame 1723 of 38846
# Saving frame 1724 of 38846
# Saving frame 1725 of 38846
# Saving frame 1726 of 38846
# Saving frame 1727 of 38846
# Saving frame 1728 of 38846
# Saving frame 1729 of 38846
# Saving frame 1730 of 38846
# Saving frame 1731 of 38846
# Saving frame 1732 of 38846
# Saving frame 1733 of 38846
# Saving frame 1734 of 38846
# Saving frame 1735 of 38846
# Saving frame 1736 of 38846
# Saving frame 1737 of 38846
# Saving frame 1738 of 38846
# Saving frame 1739 of 38846
# Saving frame 1740 of 38846
# Saving frame 1741 of 38846
# Saving frame 1742 of 38846
# Saving frame 1743 of 38846
# Saving frame 1744 of 38846
# Saving frame 1745 of 38846
# Saving frame 1746 of 38846
# Saving frame 1747 of 38846
# Saving frame 1748 of 38846
# Saving frame 1749 of 38846
# Saving frame 1750 of 38846
# Saving frame 1751 of 38846
# Saving frame 1752 of 38846
# Saving frame 1753 of 38846
# Saving frame 1754 of 38846
# Saving frame 1755 of 38846
# Saving frame 1756 of 38846
# Saving frame 1757 of 38846
# Saving frame 1758 of 38846
# Saving frame 1759 of 38846
# Saving frame 1760 of 38846
# Saving frame 1761 of 38846
# Saving frame 1762 of 38846
# Saving frame 1763 of 38846
# Saving frame 1764 of 38846
# Saving frame 1765 of 38846
# Saving frame 1766 of 38846
# Saving frame 1767 of 38846
# Saving frame 1768 of 38846
# Saving frame 1769 of 38846
# Saving frame 1770 of 38846
# Saving frame 1771 of 38846
# Saving frame 1772 of 38846
# Saving frame 1773 of 38846
# Saving frame 1774 of 38846
# Saving frame 1775 of 38846
# Saving frame 1776 of 38846
# Saving frame 1777 of 38846
# Saving frame 1778 of 38846
# Saving frame 1779 of 38846
# Saving frame 1780 of 38846
# Saving frame 1781 of 38846
# Saving frame 1782 of 38846
# Saving frame 1783 of 38846
# Saving frame 1784 of 38846
# Saving frame 1785 of 38846
# Saving frame 1786 of 38846
# Saving frame 1787 of 38846
# Saving frame 1788 of 38846
# Saving frame 1789 of 38846
# Saving frame 1790 of 38846
# Saving frame 1791 of 38846
# Saving frame 1792 of 38846
# Saving frame 1793 of 38846
# Saving frame 1794 of 38846
# Saving frame 1795 of 38846
# Saving frame 1796 of 38846
# Saving frame 1797 of 38846
# Saving frame 1798 of 38846
# Saving frame 1799 of 38846
# Saving frame 1800 of 38846
# Saving frame 1801 of 38846
# Saving frame 1802 of 38846
# Saving frame 1803 of 38846
# Saving frame 1804 of 38846
# Saving frame 1805 of 38846
# Saving frame 1806 of 38846
# Saving frame 1807 of 38846
# Saving frame 1808 of 38846
# Saving frame 1809 of 38846
# Saving frame 1810 of 38846
# Saving frame 1811 of 38846
# Saving frame 1812 of 38846
# Saving frame 1813 of 38846
# Saving frame 1814 of 38846
# Saving frame 1815 of 38846
# Saving frame 1816 of 38846
# ...
# Saving frame 38275 of 38846
# Saving frame 38276 of 38846
# Saving frame 38277 of 38846
# Saving frame 38278 of 38846
# Saving frame 38279 of 38846
# Saving frame 38280 of 38846
# Saving frame 38281 of 38846
# Saving frame 38282 of 38846
# Saving frame 38283 of 38846
# Saving frame 38284 of 38846
# Saving frame 38285 of 38846
# Saving frame 38286 of 38846
# Saving frame 38287 of 38846
# Saving frame 38288 of 38846
# Saving frame 38289 of 38846
# Saving frame 38290 of 38846
# Saving frame 38291 of 38846
# Saving frame 38292 of 38846
# Saving frame 38293 of 38846
# Saving frame 38294 of 38846
# Saving frame 38295 of 38846
# Saving frame 38296 of 38846
# Saving frame 38297 of 38846
# Saving frame 38298 of 38846
# Saving frame 38299 of 38846
# Saving frame 38300 of 38846
# Saving frame 38301 of 38846
# Saving frame 38302 of 38846
# Saving frame 38303 of 38846
# Saving frame 38304 of 38846
# Saving frame 38305 of 38846
# Saving frame 38306 of 38846
# Saving frame 38307 of 38846
# Saving frame 38308 of 38846
# Saving frame 38309 of 38846
# Saving frame 38310 of 38846
# Saving frame 38311 of 38846
# Saving frame 38312 of 38846
# Saving frame 38313 of 38846
# Saving frame 38314 of 38846
# Saving frame 38315 of 38846
# Saving frame 38316 of 38846
# Saving frame 38317 of 38846
# Saving frame 38318 of 38846
# Saving frame 38319 of 38846
# Saving frame 38320 of 38846
# Saving frame 38321 of 38846
# Saving frame 38322 of 38846
# Saving frame 38323 of 38846
# Saving frame 38324 of 38846
# Saving frame 38325 of 38846
# Saving frame 38326 of 38846
# Saving frame 38327 of 38846
# Saving frame 38328 of 38846
# Saving frame 38329 of 38846
# Saving frame 38330 of 38846
# Saving frame 38331 of 38846
# Saving frame 38332 of 38846
# Saving frame 38333 of 38846
# Saving frame 38334 of 38846
# Saving frame 38335 of 38846
# Saving frame 38336 of 38846
# Saving frame 38337 of 38846
# Saving frame 38338 of 38846
# Saving frame 38339 of 38846
# Saving frame 38340 of 38846
# Saving frame 38341 of 38846
# Saving frame 38342 of 38846
# Saving frame 38343 of 38846
# Saving frame 38344 of 38846
# Saving frame 38345 of 38846
# Saving frame 38346 of 38846
# Saving frame 38347 of 38846
# Saving frame 38348 of 38846
# Saving frame 38349 of 38846
# Saving frame 38350 of 38846
# Saving frame 38351 of 38846
# Saving frame 38352 of 38846
# Saving frame 38353 of 38846
# Saving frame 38354 of 38846
# Saving frame 38355 of 38846
# Saving frame 38356 of 38846
# Saving frame 38357 of 38846
# Saving frame 38358 of 38846
# Saving frame 38359 of 38846
# Saving frame 38360 of 38846
# Saving frame 38361 of 38846
# Saving frame 38362 of 38846
# Saving frame 38363 of 38846
# Saving frame 38364 of 38846
# Saving frame 38365 of 38846
# Saving frame 38366 of 38846
# Saving frame 38367 of 38846
# Saving frame 38368 of 38846
# Saving frame 38369 of 38846
# Saving frame 38370 of 38846
# Saving frame 38371 of 38846
# Saving frame 38372 of 38846
# Saving frame 38373 of 38846
# Saving frame 38374 of 38846
# Saving frame 38375 of 38846
# Saving frame 38376 of 38846
# Saving frame 38377 of 38846
# Saving frame 38378 of 38846
# Saving frame 38379 of 38846
# Saving frame 38380 of 38846
# Saving frame 38381 of 38846
# Saving frame 38382 of 38846
# Saving frame 38383 of 38846
# Saving frame 38384 of 38846
# Saving frame 38385 of 38846
# Saving frame 38386 of 38846
# Saving frame 38387 of 38846
# Saving frame 38388 of 38846
# Saving frame 38389 of 38846
# Saving frame 38390 of 38846
# Saving frame 38391 of 38846
# Saving frame 38392 of 38846
# Saving frame 38393 of 38846
# Saving frame 38394 of 38846
# Saving frame 38395 of 38846
# Saving frame 38396 of 38846
# Saving frame 38397 of 38846
# Saving frame 38398 of 38846
# Saving frame 38399 of 38846
# Saving frame 38400 of 38846
# Saving frame 38401 of 38846
# Saving frame 38402 of 38846
# Saving frame 38403 of 38846
# Saving frame 38404 of 38846
# Saving frame 38405 of 38846
# Saving frame 38406 of 38846
# Saving frame 38407 of 38846
# Saving frame 38408 of 38846
# Saving frame 38409 of 38846
# Saving frame 38410 of 38846
# Saving frame 38411 of 38846
# Saving frame 38412 of 38846
# Saving frame 38413 of 38846
# Saving frame 38414 of 38846
# Saving frame 38415 of 38846
# Saving frame 38416 of 38846
# Saving frame 38417 of 38846
# Saving frame 38418 of 38846
# Saving frame 38419 of 38846
# Saving frame 38420 of 38846
# Saving frame 38421 of 38846
# Saving frame 38422 of 38846
# Saving frame 38423 of 38846
# Saving frame 38424 of 38846
# Saving frame 38425 of 38846
# Saving frame 38426 of 38846
# Saving frame 38427 of 38846
# Saving frame 38428 of 38846
# Saving frame 38429 of 38846
# Saving frame 38430 of 38846
# Saving frame 38431 of 38846
# Saving frame 38432 of 38846
# Saving frame 38433 of 38846
# Saving frame 38434 of 38846
# Saving frame 38435 of 38846
# Saving frame 38436 of 38846
# Saving frame 38437 of 38846
# Saving frame 38438 of 38846
# Saving frame 38439 of 38846
# Saving frame 38440 of 38846
# Saving frame 38441 of 38846
# Saving frame 38442 of 38846
# Saving frame 38443 of 38846
# Saving frame 38444 of 38846
# Saving frame 38445 of 38846
# Saving frame 38446 of 38846
# Saving frame 38447 of 38846
# Saving frame 38448 of 38846
# Saving frame 38449 of 38846
# Saving frame 38450 of 38846
# Saving frame 38451 of 38846
# Saving frame 38452 of 38846
# Saving frame 38453 of 38846
# Saving frame 38454 of 38846
# Saving frame 38455 of 38846
# Saving frame 38456 of 38846
# Saving frame 38457 of 38846
# Saving frame 38458 of 38846
# Saving frame 38459 of 38846
# Saving frame 38460 of 38846
# Saving frame 38461 of 38846
# Saving frame 38462 of 38846
# Saving frame 38463 of 38846
# Saving frame 38464 of 38846
# Saving frame 38465 of 38846
# Saving frame 38466 of 38846
# Saving frame 38467 of 38846
# Saving frame 38468 of 38846
# Saving frame 38469 of 38846
# Saving frame 38470 of 38846
# Saving frame 38471 of 38846
# Saving frame 38472 of 38846
# Saving frame 38473 of 38846
# Saving frame 38474 of 38846
# Saving frame 38475 of 38846
# Saving frame 38476 of 38846
# Saving frame 38477 of 38846
# Saving frame 38478 of 38846
# Saving frame 38479 of 38846
# Saving frame 38480 of 38846
# Saving frame 38481 of 38846
# Saving frame 38482 of 38846
# Saving frame 38483 of 38846
# Saving frame 38484 of 38846
# Saving frame 38485 of 38846
# Saving frame 38486 of 38846
# Saving frame 38487 of 38846
# Saving frame 38488 of 38846
# Saving frame 38489 of 38846
# Saving frame 38490 of 38846
# Saving frame 38491 of 38846
# Saving frame 38492 of 38846
# Saving frame 38493 of 38846
# Saving frame 38494 of 38846
# Saving frame 38495 of 38846
# Saving frame 38496 of 38846
# Saving frame 38497 of 38846
# Saving frame 38498 of 38846
# Saving frame 38499 of 38846
# Saving frame 38500 of 38846
# Saving frame 38501 of 38846
# Saving frame 38502 of 38846
# Saving frame 38503 of 38846
# Saving frame 38504 of 38846
# Saving frame 38505 of 38846
# Saving frame 38506 of 38846
# Saving frame 38507 of 38846
# Saving frame 38508 of 38846
# Saving frame 38509 of 38846
# Saving frame 38510 of 38846
# Saving frame 38511 of 38846
# Saving frame 38512 of 38846
# Saving frame 38513 of 38846
# Saving frame 38514 of 38846
# Saving frame 38515 of 38846
# Saving frame 38516 of 38846
# Saving frame 38517 of 38846
# Saving frame 38518 of 38846
# Saving frame 38519 of 38846
# Saving frame 38520 of 38846
# Saving frame 38521 of 38846
# Saving frame 38522 of 38846
# Saving frame 38523 of 38846
# Saving frame 38524 of 38846
# Saving frame 38525 of 38846
# Saving frame 38526 of 38846
# Saving frame 38527 of 38846
# Saving frame 38528 of 38846
# Saving frame 38529 of 38846
# Saving frame 38530 of 38846
# Saving frame 38531 of 38846
# Saving frame 38532 of 38846
# Saving frame 38533 of 38846
# Saving frame 38534 of 38846
# Saving frame 38535 of 38846
# Saving frame 38536 of 38846
# Saving frame 38537 of 38846
# Saving frame 38538 of 38846
# Saving frame 38539 of 38846
# Saving frame 38540 of 38846
# Saving frame 38541 of 38846
# Saving frame 38542 of 38846
# Saving frame 38543 of 38846
# Saving frame 38544 of 38846
# Saving frame 38545 of 38846
# Saving frame 38546 of 38846
# Saving frame 38547 of 38846
# Saving frame 38548 of 38846
# Saving frame 38549 of 38846
# Saving frame 38550 of 38846
# Saving frame 38551 of 38846
# Saving frame 38552 of 38846
# Saving frame 38553 of 38846
# Saving frame 38554 of 38846
# Saving frame 38555 of 38846
# Saving frame 38556 of 38846
# Saving frame 38557 of 38846
# Saving frame 38558 of 38846
# Saving frame 38559 of 38846
# Saving frame 38560 of 38846
# Saving frame 38561 of 38846
# Saving frame 38562 of 38846
# Saving frame 38563 of 38846
# Saving frame 38564 of 38846
# Saving frame 38565 of 38846
# Saving frame 38566 of 38846
# Saving frame 38567 of 38846
# Saving frame 38568 of 38846
# Saving frame 38569 of 38846
# Saving frame 38570 of 38846
# Saving frame 38571 of 38846
# Saving frame 38572 of 38846
# Saving frame 38573 of 38846
# Saving frame 38574 of 38846
# Saving frame 38575 of 38846
# Saving frame 38576 of 38846
# Saving frame 38577 of 38846
# Saving frame 38578 of 38846
# Saving frame 38579 of 38846
# Saving frame 38580 of 38846
# Saving frame 38581 of 38846
# Saving frame 38582 of 38846
# Saving frame 38583 of 38846
# Saving frame 38584 of 38846
# Saving frame 38585 of 38846
# Saving frame 38586 of 38846
# Saving frame 38587 of 38846
# Saving frame 38588 of 38846
# Saving frame 38589 of 38846
# Saving frame 38590 of 38846
# Saving frame 38591 of 38846
# Saving frame 38592 of 38846
# Saving frame 38593 of 38846
# Saving frame 38594 of 38846
# Saving frame 38595 of 38846
# Saving frame 38596 of 38846
# Saving frame 38597 of 38846
# Saving frame 38598 of 38846
# Saving frame 38599 of 38846
# Saving frame 38600 of 38846
# Saving frame 38601 of 38846
# Saving frame 38602 of 38846
# Saving frame 38603 of 38846
# Saving frame 38604 of 38846
# Saving frame 38605 of 38846
# Saving frame 38606 of 38846
# Saving frame 38607 of 38846
# Saving frame 38608 of 38846
# Saving frame 38609 of 38846
# Saving frame 38610 of 38846
# Saving frame 38611 of 38846
# Saving frame 38612 of 38846
# Saving frame 38613 of 38846
# Saving frame 38614 of 38846
# Saving frame 38615 of 38846
# Saving frame 38616 of 38846
# Saving frame 38617 of 38846
# Saving frame 38618 of 38846
# Saving frame 38619 of 38846
# Saving frame 38620 of 38846
# Saving frame 38621 of 38846
# Saving frame 38622 of 38846
# Saving frame 38623 of 38846
# Saving frame 38624 of 38846
# Saving frame 38625 of 38846
# Saving frame 38626 of 38846
# Saving frame 38627 of 38846
# Saving frame 38628 of 38846
# Saving frame 38629 of 38846
# Saving frame 38630 of 38846
# Saving frame 38631 of 38846
# Saving frame 38632 of 38846
# Saving frame 38633 of 38846
# Saving frame 38634 of 38846
# Saving frame 38635 of 38846
# Saving frame 38636 of 38846
# Saving frame 38637 of 38846
# Saving frame 38638 of 38846
# Saving frame 38639 of 38846
# Saving frame 38640 of 38846
# Saving frame 38641 of 38846
# Saving frame 38642 of 38846
# Saving frame 38643 of 38846
# Saving frame 38644 of 38846
# Saving frame 38645 of 38846
# Saving frame 38646 of 38846
# Saving frame 38647 of 38846
# Saving frame 38648 of 38846
# Saving frame 38649 of 38846
# Saving frame 38650 of 38846
# Saving frame 38651 of 38846
# Saving frame 38652 of 38846
# Saving frame 38653 of 38846
# Saving frame 38654 of 38846
# Saving frame 38655 of 38846
# Saving frame 38656 of 38846
# Saving frame 38657 of 38846
# Saving frame 38658 of 38846
# Saving frame 38659 of 38846
# Saving frame 38660 of 38846
# Saving frame 38661 of 38846
# Saving frame 38662 of 38846
# Saving frame 38663 of 38846
# Saving frame 38664 of 38846
# Saving frame 38665 of 38846
# Saving frame 38666 of 38846
# Saving frame 38667 of 38846
# Saving frame 38668 of 38846
# Saving frame 38669 of 38846
# Saving frame 38670 of 38846
# Saving frame 38671 of 38846
# Saving frame 38672 of 38846
# Saving frame 38673 of 38846
# Saving frame 38674 of 38846
# Saving frame 38675 of 38846
# Saving frame 38676 of 38846
# Saving frame 38677 of 38846
# Saving frame 38678 of 38846
# Saving frame 38679 of 38846
# Saving frame 38680 of 38846
# Saving frame 38681 of 38846
# Saving frame 38682 of 38846
# Saving frame 38683 of 38846
# Saving frame 38684 of 38846
# Saving frame 38685 of 38846
# Saving frame 38686 of 38846
# Saving frame 38687 of 38846
# Saving frame 38688 of 38846
# Saving frame 38689 of 38846
# Saving frame 38690 of 38846
# Saving frame 38691 of 38846
# Saving frame 38692 of 38846
# Saving frame 38693 of 38846
# Saving frame 38694 of 38846
# Saving frame 38695 of 38846
# Saving frame 38696 of 38846
# Saving frame 38697 of 38846
# Saving frame 38698 of 38846
# Saving frame 38699 of 38846
# Saving frame 38700 of 38846
# Saving frame 38701 of 38846
# Saving frame 38702 of 38846
# Saving frame 38703 of 38846
# Saving frame 38704 of 38846
# Saving frame 38705 of 38846
# Saving frame 38706 of 38846
# Saving frame 38707 of 38846
# Saving frame 38708 of 38846
# Saving frame 38709 of 38846
# Saving frame 38710 of 38846
# Saving frame 38711 of 38846
# Saving frame 38712 of 38846
# Saving frame 38713 of 38846
# Saving frame 38714 of 38846
# Saving frame 38715 of 38846
# Saving frame 38716 of 38846
# Saving frame 38717 of 38846
# Saving frame 38718 of 38846
# Saving frame 38719 of 38846
# Saving frame 38720 of 38846
# Saving frame 38721 of 38846
# Saving frame 38722 of 38846
# Saving frame 38723 of 38846
# Saving frame 38724 of 38846
# Saving frame 38725 of 38846
# Saving frame 38726 of 38846
# Saving frame 38727 of 38846
# Saving frame 38728 of 38846
# Saving frame 38729 of 38846
# Saving frame 38730 of 38846
# Saving frame 38731 of 38846
# Saving frame 38732 of 38846
# Saving frame 38733 of 38846
# Saving frame 38734 of 38846
# Saving frame 38735 of 38846
# Saving frame 38736 of 38846
# Saving frame 38737 of 38846
# Saving frame 38738 of 38846
# Saving frame 38739 of 38846
# Saving frame 38740 of 38846
# Saving frame 38741 of 38846
# Saving frame 38742 of 38846
# Saving frame 38743 of 38846
# Saving frame 38744 of 38846
# Saving frame 38745 of 38846
# Saving frame 38746 of 38846
# Saving frame 38747 of 38846
# Saving frame 38748 of 38846
# Saving frame 38749 of 38846
# Saving frame 38750 of 38846
# Saving frame 38751 of 38846
# Saving frame 38752 of 38846
# Saving frame 38753 of 38846
# Saving frame 38754 of 38846
# Saving frame 38755 of 38846
# Saving frame 38756 of 38846
# Saving frame 38757 of 38846
# Saving frame 38758 of 38846
# Saving frame 38759 of 38846
# Saving frame 38760 of 38846
# Saving frame 38761 of 38846
# Saving frame 38762 of 38846
# Saving frame 38763 of 38846
# Saving frame 38764 of 38846
# Saving frame 38765 of 38846
# Saving frame 38766 of 38846
# Saving frame 38767 of 38846
# Saving frame 38768 of 38846
# Saving frame 38769 of 38846
# Saving frame 38770 of 38846
# Saving frame 38771 of 38846
# Saving frame 38772 of 38846
# Saving frame 38773 of 38846
# Saving frame 38774 of 38846
# Saving frame 38775 of 38846
# Saving frame 38776 of 38846
# Saving frame 38777 of 38846
# Saving frame 38778 of 38846
# Saving frame 38779 of 38846
# Saving frame 38780 of 38846
# Saving frame 38781 of 38846
# Saving frame 38782 of 38846
# Saving frame 38783 of 38846
# Saving frame 38784 of 38846
# Saving frame 38785 of 38846
# Saving frame 38786 of 38846
# Saving frame 38787 of 38846
# Saving frame 38788 of 38846
# Saving frame 38789 of 38846
# Saving frame 38790 of 38846
# Saving frame 38791 of 38846
# Saving frame 38792 of 38846
# Saving frame 38793 of 38846
# Saving frame 38794 of 38846
# Saving frame 38795 of 38846
# Saving frame 38796 of 38846
# Saving frame 38797 of 38846
# Saving frame 38798 of 38846
# Saving frame 38799 of 38846
# Saving frame 38800 of 38846
# Saving frame 38801 of 38846
# Saving frame 38802 of 38846
# Saving frame 38803 of 38846
# Saving frame 38804 of 38846
# Saving frame 38805 of 38846
# Saving frame 38806 of 38846
# Saving frame 38807 of 38846
# Saving frame 38808 of 38846
# Saving frame 38809 of 38846
# Saving frame 38810 of 38846
# Saving frame 38811 of 38846
# Saving frame 38812 of 38846
# Saving frame 38813 of 38846
# Saving frame 38814 of 38846
# Saving frame 38815 of 38846
# Saving frame 38816 of 38846
# Saving frame 38817 of 38846
# Saving frame 38818 of 38846
# Saving frame 38819 of 38846
# Saving frame 38820 of 38846
# Saving frame 38821 of 38846
# Saving frame 38822 of 38846
# Saving frame 38823 of 38846
# Saving frame 38824 of 38846
# Saving frame 38825 of 38846
# Saving frame 38826 of 38846
# Saving frame 38827 of 38846
# Saving frame 38828 of 38846
# Saving frame 38829 of 38846
# Saving frame 38830 of 38846
# Saving frame 38831 of 38846
# Saving frame 38832 of 38846
# Saving frame 38833 of 38846
# Saving frame 38834 of 38846
# Saving frame 38835 of 38846
# Saving frame 38836 of 38846
# Saving frame 38837 of 38846
# Saving frame 38838 of 38846
# Saving frame 38839 of 38846
# Saving frame 38840 of 38846
# Saving frame 38841 of 38846
# Saving frame 38842 of 38846
# Saving frame 38843 of 38846
# Saving frame 38844 of 38846
# Saving frame 38845 of 38846
# saved!

# %%
#start a second simulation starting with the ending surface of the first 
# as the initial surface

#create 1d sim and graph number of steps over time
cycle_sim =  Simulation(f2d, (test_2d_asym.shape[0],test_2d_asym.shape[1]), method=test_2d_asym.method, rtol=test_2d_asym.rtol)

#keep general params same
cycle_sim.layermax = round(test_2d_asym.layermax * 1.5) #make sure it reaches steady state
cycle_sim.float_params['DoverdeltaX2'] = test_2d_asym.float_params['DoverdeltaX2'] 
cycle_sim.sigma0 = test_2d_asym.sigma0
cycle_sim.center_reduction = test_2d_asym.center_reduction
cycle_sim.deltaT = test_2d_asym.deltaT #increase time step to decrease number of steps saved?
cycle_sim.noisy_init = test_2d_asym.noisy_init

#set up initial surface
cycle_sim.nonstd_init = True
ntots = test_2d_asym.getNtot()
cycle_sim.startingNtot = ntots[len(ntots)//2] #start with the middle of the last simulation, before discretzation error

#set to ablation run
#cycle_sim.sigmastepmax = -0.01
#set to growth run
cycle_sim.sigmastepmax = 0.20

# %%
#animate ablation of growth ending surface
anim = cycle_sim.animate(ret=True, focus_on_growth=True, proportionalSpeed=False)

# %%
#graph number of steps over time
Ntot = test_2d_asym.getNtot()
#Ntot = cycle_sim.getNtot()

maxes = np.array([np.max(n) for n in Ntot[:]])
mins = np.array([np.min(n) for n in Ntot[:]])

#print(maxes,mins)
plt.figure()
ax = plt.subplot(111)

ax.set_ylabel('Number of steps on surface')

if test_2d_asym.sigmastepmax < 0: #ablation case
    ax.set_xlabel('Total number of layers ablated')
    ax.plot( Ntot[::-1,0,0]+test_2d_asym.layermax,maxes-mins) #flipping to show ablation progress from left to right, adding layermax to show # layers ablated instead of negative # layers grown
else: #growth case   
    ax.set_xlabel('Total number of layers grown')
    ax.plot( Ntot[:,0,0],maxes-mins)

plt.grid()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
#save the animation as a gif, trying this since Simulation.save_animation is not working
#anim.save(my_filename+'.gif',writer=PillowWriter(fps=60))

# %%
#save animation with built in Simulation method
test_2d_asym.save_animation(my_filename, 'gif')

# %%
#plot at specific timesteps
#cmpltion = 0.005 
#cmpltion = 0.1
#sim = test_2d_asym
sim = cycle_sim

for cmpltion in [0.9]:#[0.33,0.50,0.55,0.66,0.8,0.9]:  #[0,0.001,0.005]: # making plots of initial noise dissipating
    plt.close()
    sim.plot(completion=cmpltion, ice=True, figurename=my_filename+'_completion'+str(cmpltion))
    #plt.savefig(my_filename+'_completion'+str(cmpltion)+'.png')

# %%
plt.savefig(''.join([i+'_' for i in my_id])+'.png')

# %%
#save the simulation to a pickle file for later use (without re-running the simulation)
test_2d_asym.save(id=my_id)

#manually save it and add compression since the 1000 layter simulation is too big
# import pickle
# import bz2
# id=['asymmetric'+str(test_2d_asym.shape[0])+'_'+str(test_2d_asym.shape[1]),str(test_2d_asym.layermax)+'layers']
# id = ''.join('_'+i for i in id)
# filename = test_2d_asym.model.__name__+'_simulation'+id+'.pkl'
# with open(filename, 'wb') as f:
#     print("saving to", f)
#     pickle.dump(test_2d_asym, bz2.BZ2File(f, 'w'))

# %% [markdown]
# 1D model for comparison (uses same parameters as above 2d model), graphing if it also reaching steady state

# %%
#create 1d sim and graph number of steps over time
ss_1d = Simulation(f1d, (test_2d_asym.shape[0],), method=test_2d_asym.method, rtol=test_2d_asym.rtol)

ss_1d.float_params['DoverdeltaX2'] = test_2d_asym.float_params['DoverdeltaX2'] 
ss_1d.layermax = test_2d_asym.layermax * 1.5 #make sure it reaches steady state
ss_1d.sigmastepmax = test_2d_asym.sigmastepmax 
ss_1d.sigma0 = test_2d_asym.sigma0
ss_1d.center_reduction = test_2d_asym.center_reduction
ss_1d.deltaT = test_2d_asym.deltaT #increase time step to decrease number of steps saved?
ss_1d.noisy_init = test_2d_asym.noisy_init

# %%
#set the id 
my_id=['nx_'+str(ss_1d.shape[0]),str(ss_1d.layermax)+'layers',
                                'center_reduction'+str(ss_1d.center_reduction),  'D_2', ss_1d.method, 'sigmamax_'+str(ss_1d.sigmastepmax) +'noisyinit_'+str(ss_1d.noisy_init)]
my_filename = ''.join([i+'_' for i in my_id])

# %%
fignum = 0
plt.close(fignum)
#print number of steps over time
Ntot = ss_1d.getNtot()

maxes = np.array([np.max(n) for n in Ntot[:]])
mins = np.array([np.min(n) for n in Ntot[:]])

#print(maxes,mins)
plt.figure(fignum)
ax = plt.subplot(111)

#ax.plot(test_f2d_sim.results()['t'],maxes-mins)
ax.plot(Ntot[:,0],maxes-mins)
ax.set_ylabel('Number of steps on surface')
ax.set_xlabel('Time')
plt.grid()
plt.show()

# %%
plt.close('1d surface over time 3d surface')
plt.figure('1d surface over time 3d surface')
#plot surface over time as 3d surface
ax = plt.axes(projection='3d')



zs = ss_1d.getNtot()
start,stop = 0, zs.shape[0]
#crop time selection
start,stop = stop*5//6, stop
zs = zs[start:stop]

t,x = [*zs.shape]
print(x,t)
xs,ys = np.meshgrid(np.linspace(0,x,x),np.linspace(start,stop,stop-start))

#print shapes of inputs
print(xs.shape,ys.shape,zs.shape)

#contour levels
levels = np.linspace(740,880,10)

#plot contours of the surface
ax.contour(X=xs, Y=ys, Z=zs,  label='ice+QLL', cmap='viridis_r')

#plot the surface with reversed viridis
ax.plot_surface(X=xs, Y=ys, Z=zs,  label='ice+QLL', cmap='viridis_r')

ax.set_xlabel('nx')
ax.set_ylabel('Time steps')
#ax.set_xlabel(r'x ($\mu m$)')
#ax.set_ylabel('Layers of ice')
plt.show()

# %%
#plot contours over time on one surface
from turtle import position


ax = plt.axes(projection='3d')



zs = ss_1d.getNtot()
start,stop = 0, zs.shape[0]
#crop time selection
#start,stop = stop*5//6, stop
zs = zs[start:stop]

t,x = [*zs.shape]
print(x,t)
xs,ys = np.meshgrid(np.linspace(0,x,x),np.linspace(start,stop,stop-start))

#print shapes of inputs
print(xs.shape,ys.shape,zs.shape)

# #contour levels
# levels = np.linspace(740,880,10)

# #plot the surface with reversed viridis
# ax.contour(X=xs, Y=ys, Z=zs,  label='ice+QLL', cmap='viridis_r')

# ax.set_xlabel('nx')
# ax.set_ylabel('Time steps')
# #ax.set_xlabel(r'x ($\mu m$)')
# #ax.set_ylabel('Layers of ice')
# plt.show()

ix = 100
plt.figure()

ixlist = [0, 10_000, 30_000, 40_000]#np.linspace(0,7400, 100)
offset = 1
for ix in ixlist:
    tempzs = zs[ix,:] - min(zs[ix,:]) + offset
    offset += 1
    plt.plot(xs[ix,:], tempzs,label = 'x = '+str(ix))

#plt.legend()

# %%
#plot 
#cmpltion = 0.005 
cmpltion = 0.3

#for cmpltion in map(lambda x: x*3,[0,0.001,0.005]): # making plots of initial noise dissipating
ss_1d.plot(completion=cmpltion, ice=True)#, figurename=my_filename+'_completion'+str(cmpltion))
plt.show()

# %%
ss_1d.animate()

# %%
plt.close()

# %%
#test_2d_asym.save(id=['asymmetric'+str(test_2d_asym.shape[0])+'_'+str(test_2d_asym.shape[1]),str(test_2d_asym.layermax)+'layers'])
#symm = Simulation(f2d,(500,500),rtol=1e-12)

# %%
#countour plot of sigmastep 2d
plt.figure()
ax = plt.axes(projection='3d')
plt.xlabel(r'x ($\mu m$)')
plt.ylabel(r'y ($\mu m$)')
#ax.set_zlabel('Layers of ice')
#levels = np.arange(19,21,0.1)
ax.contourf(xgrid,ygrid, sigma*100, extent=(0, 2, 0, 2), cmap='YlGnBu_r', vmin=0, vmax=200, zorder=1)#, levels=levels)

# %%
#countour plot of sigmastep 2d
print(xs.shape,ys.shape,sigma.shape)
fig,ax = plt.subplots()
CS = ax.contourf(xs.T,ys.T,sigma*100)
ax.set_xlabel(r'$x (\mu m)$', fontsize=20)
ax.set_ylabel(r'$y (\mu m)$', fontsize=20)
plt.grid(True)
plt.gca().set_aspect('equal')
fig.colorbar(CS)
plt.title('%supersaturation (getsigmastep_2d)')

# %% [markdown]
# 2D Growth simulation

# %%
#create the 2d sim
test_f2d_sim = Simulation(f2d, (250,250), rtol=1e-12)
test_f2d_sim.layermax = 50#0
#test_f2d_sim.run()
#test_f2d_sim.save(_id=['test','50layer'])

# %%
#animate the 2d sim
test_f2d_sim.animate(crossSection=True)

# %%
#print variables in 1d simulation for comparison to literature
for k,v in test_f2d_sim._extra_vars.items():
    print(k,v)
print('center reduction %: ', test_f2d_sim.center_reduction)

# %%
#print number of steps over time
Ntot = test_f2d_sim.getNtot()

maxes = np.array([np.max(n) for n in Ntot[:]])
mins = np.array([np.min(n) for n in Ntot[:]])

#print(maxes,mins)
plt.figure()
ax = plt.subplot(111)

#ax.plot(test_f2d_sim.results()['t'],maxes-mins)
ax.plot(Ntot[:,0,0],maxes-mins)
#ax.plot(test_f2d_sim.results()['t'],test_f2d_sim.results()['t'])
plt.grid()

# %%
#animate test_f2d_sim

test_f2d_sim.animate(ice=True)

# %%
#test_f2d_sim = loadSim('f2d_simulation_test_50layer.pkl')

# %%
#graph results normalized to minimum of ice surface
Fliq_ss, Ntot_steadystate = test_f2d_sim.normalize_results_to_min()
nice_ss = Ntot_steadystate-Fliq_ss
print(np.shape(Ntot_steadystate))
xs, ys = np.meshgrid(test_f2d_sim.x, test_f2d_sim.y)

fig = plt.figure(figsize=(12,12))
ax = plt.axes(projection = '3d')
#ax.plot_surface(test_f2d_sim._results['t'], Ntot_steadystate[:,])
ax.set_xlabel(r'$x (\mu m$)')#,fontsize=fontsize)
ax.set_ylabel(r'$y (\mu m$)')#,fontsize=fontsize)
ax.set_zlabel(r'$ice \ layers$')#,fontsize=fontsize)
#limits
#ax.set_zlim3d(-self.layermax, self.layermax)
#ax.set_ylim(0, max(self.y))
#ax.set_xlim(0, max(self.x))
def update_fig(num):
    ax.clear() # remove last iteration of plot 
    plot_func = ax.plot_surface
    # if crossSection:
    #     xmid = round(np.shape(Nice)[0]/2)
    #     if ice:
    #         plot_func(X=xs[xmid:], Y=ys[xmid:], Z=nice_ss[num][xmid:][:],cmap ='viridis')# cmap='viridis')#, vmin=0, vmax=200) #plot half of the surface of the ice
    #     if tot:
    #         plot_func(X=xs[xmid:], Y=ys[xmid:], Z=Ntot_steadystate[num][xmid:][:], cmap='cividis')#, vmin=0, vmax=200) #plot half the surface of the QLL
    # else:
    #     if ice:
    plot_func(X=xs, Y=ys, Z=nice_ss[num], cmap='viridis')#, vmin=0, vmax=200) #plot the surface of the ice 
        # if tot:
    # plot_func(X=xs, Y=ys, Z=Ntot_steadystate[num], cmap='YlGnBu_r')#, vmin=0, vmax=200)#plot the surface of the QLL
    pass


num_steps = len(test_f2d_sim._results['t'])
import matplotlib.animation as animation
ani = animation.FuncAnimation(fig , update_fig, num_steps, interval=50, blit=False, cache_frame_data=False, repeat = True)
plt.show()

# %%
#graph difference in steps over time: should converge to zero if steady state is reached
Fliq_ss, Ntot_steadystate = test_f2d_sim.steady_state_calc()
nice_ss = Ntot_steadystate-Fliq_ss
print(np.shape(Ntot_steadystate))
xs, ys = np.meshgrid(test_f2d_sim.x, test_f2d_sim.y)

fig = plt.figure(figsize=(12,12))
ax = plt.axes(projection = '3d')
#ax.plot_surface(test_f2d_sim._results['t'], Ntot_steadystate[:,])
ax.set_xlabel(r'$x (\mu m$)')#,fontsize=fontsize)
ax.set_ylabel(r'$y (\mu m$)')#,fontsize=fontsize)
ax.set_zlabel(r'$ice \ layers$')#,fontsize=fontsize)
#limits
#ax.set_zlim3d(-self.layermax, self.layermax)
#ax.set_ylim(0, max(self.y))
#ax.set_xlim(0, max(self.x))
def update_fig(num):
    ax.clear() # remove last iteration of plot 
    plot_func = ax.plot_surface
    # if crossSection:
    #     xmid = round(np.shape(Nice)[0]/2)
    #     if ice:
    #         plot_func(X=xs[xmid:], Y=ys[xmid:], Z=nice_ss[num][xmid:][:],cmap ='viridis')# cmap='viridis')#, vmin=0, vmax=200) #plot half of the surface of the ice
    #     if tot:
    #         plot_func(X=xs[xmid:], Y=ys[xmid:], Z=Ntot_steadystate[num][xmid:][:], cmap='cividis')#, vmin=0, vmax=200) #plot half the surface of the QLL
    # else:
    #     if ice:
    plot_func(X=xs, Y=ys, Z=nice_ss[num], cmap='viridis')#, vmin=0, vmax=200) #plot the surface of the ice 
        # if tot:
    # plot_func(X=xs, Y=ys, Z=Ntot_steadystate[num], cmap='YlGnBu_r')#, vmin=0, vmax=200)#plot the surface of the QLL
    pass


num_steps = len(test_f2d_sim._results['t'])
import matplotlib.animation as animation
ani = animation.FuncAnimation(fig , update_fig, num_steps, interval=50, blit=False, cache_frame_data=False, repeat = True)
plt.show()

# %%
test_2d_sim = Simulation(f2d, (500,500), rtol=1e-12)
test_2d_sim.layermax = 2
#test_2d_sim = loadSim('f2d_simulation_august13.pkl')
_plot = test_2d_sim.plot()

# %% [markdown]
# 1d simulation

# %%
test_2d_sim.save(id=['august13'])

# %%
fig = plt.figure()
ax = plt.axes(projection='3d')
num_steps = len(test_2d_sim.results()['t'])
xs,ys = np.meshgrid(test_2d_sim.x, test_2d_sim.y)
ax.plot_surface(X=xs, Y=ys, Z=test_2d_sim.getNtot()[num_steps-1], cmap='viridis')

# %%
test_1d = Simulation(f1d, shape=(500,), rtol=1e-12)
test_1d.layermax = 500
test_1d.results()

# %%
#test_1d.animate(ice=True, tot=True)
test_1d.plot()

# %% [markdown]
# 2d Idea: increase sigmastepmax to see if faceted growth occur, removing the concave "bowl" forming at the center of initially tested 2d systems (test_f2d_sim)

# %%
# sigma_test = Simulation(f2d, (500,500),rtol = 1e-12)
# sigma_test.layermax = 100
# sigma_test.sigmastepmax = 0.25
# sigma_test.results()

# %%
#sigma_id = ['sigmastepmax_'+str(round(100*sigma_test.sigmastepmax)), str(sigma_test.layermax)+'layers']
#sigma_test.save(id=sigma_id)

#test increased layers with increased sigmastep

#sigma_test = loadSim('f2d_simulation_sigmastepmax_025.pkl') # 20 layers?
#sigma_test = loadSim('f2d_simulation_sigmastepmax_025_50layers.pkl')
sigma_test = loadSim('f2d_simulation_sigmastepmax_25_100layers.pkl')

# %%
sigma_test.animate()

# %% [markdown]
# 2d Ablation testing

# %%
f2d_ablate = Simulation(f2d, (500,500), rtol=1e-12)
f2d_ablate.sigmastepmax = -0.1
f2d_ablate.layermax = 50
f2d_ablate.animate()

# %% [markdown]
# 1d growth testing. Works, however does not currently match the literature graph despite using the same parameters.

# %%
f1d_sim = Simulation(f1d, (500,), rtol=1e-12)

# %%
#change parameters to match Gladich et al paper's graph and run simulation
f1d_sim.layermax = 500#10000
#f1d_sim.center_reduction = 0.25 #is default now

# %%
f1d_sim.run()

# %%
fig = f1d_sim.plot(completion=0.99, ice=True, tot=True)

# %%
#print variables in 1d simulation for comparison to literature
for k,v in f1d_sim._extra_vars.items():
    print(k,v)
print('center reduction %: ', f1d_sim.center_reduction)

# %%
#functions tested so far
#test_f2d_sim.countermax_0D
#test_f2d_sim.countermax_1D
#test_f2d_sim.countermax_2D
#test_f2d_sim.atol
#test_f2d_sim.rtol
#test_f2d_sim.deltaT
#test_f2d_sim.float_params
#test_f2d_sim.animate()
#test_f2d_sim.run()
#test_f2d_sim.steady_state_calc()
#test_f2d_sim.plot()
#test_f2d_sim.save()
#test_f2d_sim.load() #WORKS to load simulation from file if simulation object exists already -- for loading straght froom file use loadSim()
#loadSim() #works

# %%
num_steps = len(test_f2d_sim.results()['t'])
#shape of results is (num_steps, 2, nx, ny)
Fliq, Ntot = [],[]
for step in range(num_steps):
    next_Fliq, next_Ntot = test_f2d_sim._results['y'][step]
    Fliq.append(next_Fliq)
    Ntot.append(next_Ntot)    
Fliq,Ntot = np.array(Fliq), np.array(Ntot)
Nice = Ntot - Fliq
#shape of fliq, ntot and nice should be (num_steps, nx, ny)

#access coordinate arrays for plotting
xs, ys = np.meshgrid(test_f2d_sim.x, test_f2d_sim.y)

# %%
print(num_steps)
print(test_f2d_sim.steepness(0,slice(0,test_f2d_sim.shape[0]//2)))

# %%
print(test_f2d_sim.get_step_density(0,slice(0,test_f2d_sim.shape[0]//2)))
